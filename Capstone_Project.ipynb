# %% [markdown]
# # Best Neighbourhood in Mumbai

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find best neighbourhood in Mumbai, India. As Mumbai is very busy in terms of traffic, we will find some areas which has good local trains connectivity and good amenities like restaurants, gyms, nightclub etc.
#
# This report will be targeted to stakeholders interested in buying new home in the area where they could save their travelling time and real estate agents and builders for best place to build new societies.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data<a name = data></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
#
# * train stations in Mumbai with major train halts.
# * find neighbourhood of 5Km around each major station.
# * number of restaurants, gyms, nightclub etc in each neighbourhood
#
# Following data sources will be needed to extract/generate the required information:
#
# * **wiki page** to find List of Mumbai Suburban Railway stations.
# * coordinate of of each station will be obtained using **Google Maps API geocoding**.
# * centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
# * number of restaurants, gyms, nightclub etc in every neighborhood will be obtained using **Foursquare API**

# %% [markdown]
# ### Train stations

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import re

# %%
# !wget -q -O 'List_of_Mumbai_stations.html' https://en.wikipedia.org/wiki/List_of_Mumbai_Suburban_Railway_stations
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# Find all stations in mumbai and trainlines running through them.

# %%
wiki_df = pd.DataFrame(columns = ['index', 'station', 'train lines', 'Fast train stop'])

with open("List_of_Mumbai_stations.html") as fp:
    soup = BeautifulSoup(fp)
table_str = soup.find('div', class_='mw-content-ltr')

for i in table_str.find_all('tr'):
    if i.find('td', style="text-align:center;"):
        values = []  
        values.append(i.find('td', style="text-align:center;").text)

        for j in i.find_all('a'):
            values.append(j.text)
        value_list = [values[0], values[1],(','.join(values[2:]))]
        k = i.find('img')
        if k == None:
            value_list.append(False)
        elif 'alt="☒"' in str(k):
            value_list.append(False)
        else:
            value_list.append(True)
        wiki_df = wiki_df.append(pd.Series(value_list, index=wiki_df.columns), ignore_index=True)    
        
wiki_df.set_index('index', drop = True, inplace = True) 
wiki_df
# Out:
#                                      station  \
# index
# 01                                    Airoli
# 02                                 Ambarnath
# 03                                   Ambivli
# 04                                   Andheri
# 05                                  Asangaon
# 06                                    Atgaon
# 07                                  Badlapur
# 08                             Baman Dongari
# 09                                    Bandra
# 10                                   Bhandup
# 11                                 Bhayandar
# 12                             Bhivpuri Road
# 13                                  Bhiwandi
# 14                                    Boisar
# 15                                  Borivali
# 16                                   Byculla
# 17                               CBD Belapur
# 18                               Charni Road
# 19                                   Chembur
# 20      Chhatrapati Shivaji Maharaj Terminus
# 21                               Chinchpokli
# 22                               Chunabhatti
# 23                                Churchgate
# 24                              Cotton Green
# 25                               Currey Road
# 26                             Dadar Central
# 27                               Dahanu Road
# 28                                   Dahisar
# 29                                  Dativali
# 30                                      Diva
# ...                                      ...
# 106                                    Shelu
# 107                                  Thansit
# 108                                  Targhar
# 109                                    Thane
# 110                                 Thakurli
# 111                                  Titwala
# 112                                   Turbhe
# 113                               Ulhasnagar
# 114                                Umbermali
# 115                                   Umroli
# 116                                Uran City
# 117                              Wadala Road
# 118                                 Vaitarna
# 119                                  Vangaon
# 120                                  Vangani
# 121                               Vasai Road
# 122                                    Vashi
# 123                                   Vasind
# 124                               Vidyavihar
# 125                                 Vikhroli
# 126                               Vile Parle
# 127                                    Virar
# 128                               Vithalwadi
# 129                                   Mulund
# 130                              Tilak Nagar
# 131                                    Sewri
# 132                                   Taloja
# 133                                      Pen
# 134                                 Rasayani
# 135                                Nagothane
#
#                                            train lines Fast train stop
# index
# 01                                  Trans-Harbour Line           False
# 02                                        Central Line            True
# 03                                        Central Line           False
# 04     Western Line,Harbour Line,Line 1 (Mumbai Metro)            True
# 05                                        Central Line            True
# 06                                        Central Line           False
# 07                                        Central Line            True
# 08                                     Nerul–Uran line           False
# 09                           Western Line,Harbour Line            True
# 10                                        Central Line            True
# 11                                        Western Line            True
# 12                                        Central Line           False
# 13                                        Central Line            True
# 14                                        Western Line            True
# 15                           Western Line,Harbour Line            True
# 16                                        Central Line            True
# 17                        Harbour Line,Nerul–Uran line           False
# 18                                        Western Line           False
# 19                                        Harbour Line           False
# 20                           Central Line,Harbour Line            True
# 21                                        Central Line           False
# 22                                        Harbour Line           False
# 23                                        Western Line            True
# 24                                        Harbour Line           False
# 25                                        Central Line           False
# 26             Dadar Western,Central Line,Western Line            True
# 27                                        Western Line            True
# 28                                        Western Line           False
# 29                                        Central Line           False
# 30                      Central Line,Vasai Road,Panvel            True
# ...                                                ...             ...
# 106                                       Central Line           False
# 107                                       Central Line           False
# 108                                    Nerul–Uran line           False
# 109                    Central Line,Trans-Harbour Line            True
# 110                                       Central Line           False
# 111                                       Central Line            True
# 112                                 Trans-Harbour Line           False
# 113                                       Central Line           False
# 114                                       Central Line           False
# 115                                       Western Line           False
# 116                                    Nerul–Uran line           False
# 117                                       Harbour Line           False
# 118                                       Western Line           False
# 119                                       Western Line           False
# 120                                       Central Line           False
# 121                                       Western Line            True
# 122                    Central Line,Trans-Harbour Line           False
# 123                                       Central Line           False
# 124                                       Central Line           False
# 125                                       Central Line            True
# 126                          Western Line,Harbour Line           False
# 127                                       Western Line            True
# 128                                       Central Line           False
# 129                                       Central Line            True
# 130                                       Harbour Line           False
# 131                                       Harbour Line           False
# 132                                       Central Line           False
# 133                                       Harbour Line            True
# 134                                       Harbour Line            True
# 135                                       Harbour Line            True
#
# [134 rows x 3 columns]

# %% [markdown]
# As decided by stakeholders, we will finds stations which has 2 or more train lines running through it and has halt for fast trains too.

# %%
# Train where fast train stop
station_df = wiki_df.loc[wiki_df['Fast train stop'] == True]
# Station with 2 or more train lines
station_df = station_df[station_df['train lines'].str.contains(',')]
station_df
# Out:
#                                      station  \
# index
# 04                                   Andheri
# 09                                    Bandra
# 15                                  Borivali
# 20      Chhatrapati Shivaji Maharaj Terminus
# 26                             Dadar Central
# 30                                      Diva
# 38                                 Ghatkopar
# 39                                  Goregaon
# 67                                     Kurla
# 109                                    Thane
#
#                                            train lines Fast train stop
# index
# 04     Western Line,Harbour Line,Line 1 (Mumbai Metro)            True
# 09                           Western Line,Harbour Line            True
# 15                           Western Line,Harbour Line            True
# 20                           Central Line,Harbour Line            True
# 26             Dadar Western,Central Line,Western Line            True
# 30                      Central Line,Vasai Road,Panvel            True
# 38                  Central Line,Line 1 (Mumbai Metro)            True
# 39                           Western Line,Harbour Line            True
# 67                           Central Line,Harbour Line            True
# 109                    Central Line,Trans-Harbour Line            True

# %% [markdown]
# Station with 2 or more train lines

# %% [markdown]
# ### Neighborhood Candidates

# %%
# The code was removed by Watson Studio for sharing.
google_api_key = "AIzaSyAWuAZMXEDfyhsRbHIEUAydbrsKDpAr4bY"

# %%
import requests

def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
mumbai_coordinate = get_coordinates(google_api_key, 'Mumbai, India') 

dict_coordinate = {}    
for i in station_df['station']:
    address = '%s, Mumbai, India' % (i)
    address_val = get_coordinates(google_api_key, address)
    dict_coordinate.update({address:address_val})
print(dict_coordinate)
# Out:
# {'Andheri, Mumbai, India': [19.113645, 72.8697339], 'Bandra, Mumbai, India': [19.0595596, 72.8295287], 'Borivali, Mumbai, India': [19.2307329, 72.856673], ' Chhatrapati Shivaji Maharaj Terminus, Mumbai, India': [18.9398446, 72.8354475], 'Dadar Central, Mumbai, India': [19.018769, 72.84317659999999], 'Diva, Mumbai, India': [19.1869395, 73.0477775], 'Ghatkopar, Mumbai, India': [19.0790239, 72.9080122], 'Goregaon, Mumbai, India': [19.1662566, 72.8525696], 'Kurla, Mumbai, India': [19.0726295, 72.8844721], 'Thane, Mumbai, India': [19.2183307, 72.9780897]}

# %% [markdown]
# Now let's create a grid of area candidates, Area within ~5 Km to station.
# To accurately calculate distances we need to create our grid of locations in Cartesian 2D coordinate system which allows us to calculate distances in meters (not in latitude/longitude degrees). Then we'll project those coordinates back to latitude/longitude degrees to be shown on Folium map. So let's create functions to convert between WGS84 spherical coordinate system (latitude/longitude degrees) and UTM Cartesian coordinate system (X/Y coordinates in  meters).

# %%
#!pip install shapely
#import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)
# Out:
# Requirement already satisfied: pyproj in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (2.2.1)

# %% [markdown]
# Let's create a hexagonal grid of cells: we offset every other row, and adjust vertical row spacing so that every cell center is equally distant from all it's center.

# %%
def cal_lon_lag(longitude, latitude):
    center_x, center_y = lonlat_to_xy(longitude, latitude)# City center in Cartesian coordinates
    k = math.sqrt(1) / 2
    
    x_min = center_x - 5000
    x_step = 5000
    y_min = center_y - 5000 - (int(11/k)*k*5000 - 10000)/2
    y_step = 5000 * k 

    for i in range(0, int(11/k)):
        y = y_min + i * y_step
        
        x_offset = 2500 if i%2==0 else 0
        
        for j in range(0, 11):
            x = x_min + j * x_step + x_offset
           
            distance_from_center = calc_xy_distance(center_x, center_y, x, y)
            
            if (distance_from_center <= 5001):
                lon, lat = xy_to_lonlat(x, y)
                if (format(lon, '.4f') == format(longitude, '.4f')) & \
                    (format(lat, '.4f') == format(latitude, '.4f')):
                    pass;
                else:
                    latitudes.append(lat)
                    longitudes.append(lon)
                    distances_from_center.append(distance_from_center)
                    xs.append(x)
                    ys.append(y)

xs = []
ys = []
distances_from_center = []
latitudes = []
longitudes = []  
for k,v in dict_coordinate.items():
    cal_lon_lag(v[1], v[0])
print(len(longitudes), 'candidate neighborhood centers generated.')
# Out:
# 80 candidate neighborhood centers generated.

# %% [markdown]
# Let's visualize the data we have so far: city center location and candidate neighborhood centers:

# %%
#!pip install folium
import folium

# %%
map_mumbai = folium.Map(location=mumbai_coordinate, zoom_start=13)
for i in range(0, len(latitudes)):
    folium.Marker([latitudes[i], longitudes[i]], popup="mumbai").add_to(map_mumbai)
for k,v  in dict_coordinate.items():
    folium.Marker(v, popup="mumbai").add_to(map_mumbai)
for lat, lon in zip(latitudes, longitudes):
    folium.Circle([lat, lon], radius=2500, color='blue', fill=False).add_to(map_mumbai)
    #folium.Marker([lat, lon]).add_to(map_berlin)
map_mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# OK, we now have the coordinates of centers of neighborhoods/areas to be evaluated, equally spaced (distance from every point to its station) and within ~5km from Alexanderplatz.
#
# Let's now use Google Maps API to get approximate addresses of those locations.

# %%
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Mumbai', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
addresses
# Out:
# ['Vile Parle East, Vile Parle, Maharashtra, India',
#  'C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, Vile Parle East, Maharashtra 400057, India',
#  'Navpada, Chhatrapati Shivaji International Airport Area, Vile Parle, Maharashtra 400099, India',
#  '703, Bhardawadi Rd, ICICI Colony, Amboli, Andheri West, Maharashtra 400058, India',
#  'Unnamed Road, Pereira Wadi, Asalpha, Maharashtra 400072, India',
#  '400060, Sarvodaya Nagar, MHADA Colony, Indira Nagar, Jogeshwari East, Maharashtra 400093, India',
#  'D-83, Muranjan Wadi, Marol, Andheri East, Maharashtra 400072, India',
#  'Maroshi Naka, Unit 25, Aarey Colony, Goregaon, Maharashtra 400065, India',
#  'Centre Cable of Bandra Worli Sea Link, Bandra - Worli Sea Link, 400050, India',
#  'India',
#  '2, HMA Faqir St, The Mahim Makarand CHS, Mahim West, Mahim, Maharashtra 400016, India',
#  'India',
#  '184/B, Sant Rohidas Marg, Dharavi koliwada, Dharavi Village, Dharavi, Maharashtra 400017, India',
#  '446, Govind Patil Rd, Patil Pada, Danda Village, Khar Danda, Maharashtra 400052, India',
#  'Government Colony Building No 3, JL Shirshekar Marg, Government Colony, Bandra East, Maharashtra 400051, India',
#  'Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Santacruz East, Maharashtra 400055, India',
#  'Lucky Towers, MG Cross Rd Number 4, Amrut Nagar, Patel Nagar, Kandivali, Maharashtra 400067, India',
#  'garden grove, b-1, flat no. 1301, b-wing, chikuwadi, borivali west, Maharashtra 400092, India',
#  '1st Floor, St. Lawrence High School 90 Feet Road, Opposite Kanakia Sanskruti Thakur Complex, Asha Nagar, Kandivali East, Maharashtra 400101, India',
#  'Eskay Rd, Eksar Village, Eksar, Borivali West, Maharashtra 400103, India',
#  'National Park - BMC Colony Rd, Maharashtra 400101, India',
#  'A Hill Crest, Holy cross Road I.C.Colony, near MM hospital, Borivali West, Maharashtra 400103, India',
#  'Rushi Van Borivali, Rushi Van, Next to Kajupada, Borivali East, Maharashtra 400066, India',
#  'Ghartan Pada / Chinchani Number 1, Diamond Industrial Estate, Dahisar East, Maharashtra 400068, India',
#  'Cuffe Parade, Cuffe Parade, Maharashtra 400005, India',
#  '209, Dinshaw Vacha Rd, Churchgate, Maharashtra 400020, India',
#  'Unnamed Road, Fort, Maharashtra 400001, India',
#  'India',
#  'India',
#  'Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar, Bhuleshwar, Maharashtra 400003, India',
#  'New Dock Rd, Victoria Docks Port Trust, Mazgaon, Maharashtra 400009, India',
#  'pollution response team Near mazagon Dock, Maharashtra, India',
#  'Lower Parel, Lower Parel Bridge, Lower Parel, Maharashtra 400013, India',
#  '515/A, Shankar Ghanekar Rd, Three View Co-Operative Housing Society, Opposite Bengal Chemicals, Dadar (w), Prabhadevi, Maharashtra 400025, India',
#  '12, Sakharam Lanjekar Road, Parmanand Wadi, Parel, Maharashtra 400012, India',
#  'Bandra - Worli Sea Link, Mount Mary, Bandra West, Maharashtra 400050, India',
#  'Unnamed Road, Pratiksha Nagar, BPCL Terminal, Wadala, Maharashtra 400015, India',
#  'Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Chand Hotel, Near Mahim Dargah, LJ Cross Rd, Mahim, Maharashtra 400016, India',
#  'Room no 645 rajive gandhi nagar Near New Transist Camp Antop hill Wadala, East, Maharashtra 400037, India',
#  'Shop Number.21 A Wing Kamaraj CHS Near JPR Radios, 90 Feet Road, Dharavi, Maharashtra 400017, India',
#  '802, B3, MM Valley, Nr TMC Stadium, Jilani Park Rd, Kausa, Mumbra, Thane, Maharashtra 400612, India',
#  '1, Narayan Nagar, Mumbra, Thane, Maharashtra 400612, India',
#  'Unnamed Road, Domkhar Gaon, Thane, Maharashtra 421204, India',
#  'Anant Niwas Rana Nagar No. 1, Reti Bunder Road, Rana Nagar, Retibunder, Mumbra, Thane, Maharashtra 400612, India',
#  'Casa Bella Magnifica Bus Stop, Casa Bella Main Rd, Casa Bella, PHI, Casa Bella, Usarghar, Maharashtra 421204, India',
#  'Unnamed Road, Anjur, Maharashtra 421302, India',
#  'Gavdevi Road, Betwade Gaon, Thane, Maharashtra 400612, India',
#  'Unnamed Road, Anjur, Maharashtra 421302, India',
#  '428, KN Gaikwad Marg, Ganesh Nagar, Postal Colony, Chembur, Maharashtra 400071, India',
#  'Premier Colony, Kurla West, Maharashtra 400070, India',
#  'PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maharashtra 400043, India',
#  'Andheri - Kurla Rd, Jarimari, Saki Naka, Maharashtra 400072, India',
#  'Kachra Depot Rd, Govandi Slums, Nirankar Nagar, Shivaji Nagar, Maharashtra 400043, India',
#  'B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Maharashtra 400084, India',
#  'Mumbai, Maharashtra 400079, India',
#  'C-46, LBS Rd, Godrej & Boyce Industry Estate, Vikhroli West, Maharashtra 400079, India',
#  'Bunglow no. 786, Aqsa Masjid Rd, Behind Medow Park, Gautam Nagar, Jogeshwari, Maharashtra 400102, India',
#  'JAMAATE GHURABA ALHEHADEES MADARSA MUHAMMADIA WA MASJID 1/22, LAXMI NAGAR, LINK ROAD, BESIDE GARDEN ESTATES APARTMENT NEAR, BEDROCK TYRE CO, Colony No 2, Laxmi Nagar, Goregaon West, Maharashtra 400104, India',
#  '10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon, Maharashtra 400065, India',
#  'Mumbai, Maharashtra 400095, India',
#  '400065, Workers Colony, Aarey Colony, Goregaon, Maharashtra 400065, India',
#  'Rolex Apartment, Underai Rd, Malad, Navy Colony, Mamledarwadi, Malad West, Maharashtra 400064, India',
#  'A-402, Krishna Vatika Marg, Snehadham, Azad Nagar, Gokuldham Colony, Goregaon, Maharashtra 400063, India',
#  'Unnamed Road, Malad, Shivaji Nagar, Kurar Village, Malad East, Maharashtra 400097, India',
#  'B/23, Highway Apartment., 2nd floor., Eastern Express Highway, Sion (E, Maharashtra 400022, India',
#  'Bdb Gate 1, G Block BKC, Bandra Kurla Complex, Bandra East, Maharashtra 400051, India',
#  'Shiv Shakti Shopping Complex, Deepak Kumar Marg, Swastik Park, Chembur, Maharashtra 400071, India',
#  'P and T Colony Rd, P and T Colony, Chhatrapati Shivaji International Airport Area, Santacruz East, Maharashtra 400029, India',
#  '25, Prakash Thorat Marg, Gaikwad nagar, Budha Nagar, Chedda Nagar, Maharashtra 400071, India',
#  'Hashimpremji, Shop No-2, Navpada, Vile Parle East, Vile Parle, Maharashtra 400099, India',
#  'Shop No. 1, Ground Floor, Vallabh Vihar, Opp. Kotak Mahindra Bank, MG Road, Rajawadi Colony, Ghatkopar East, Maharashtra 400077, India',
#  '329, Subhash Nagar, Mohili, Asalpha, Maharashtra 400084, India',
#  'Shri Ganesh Rahivasi Seva Sangh, Khale Compound, Next Nakshatra Residency, Near Talwalkars Gym, Panch Pakhdi, Thane West, Maharashtra 400602, India',
#  '1, Pokharan Rd Number 1, Shastri Nagar, Vartak Nagar, Thane West, Thane, Maharashtra 400606, India',
#  'Saket - Kalwa Rd, Rabodi, Thane West, Thane, Maharashtra 400601, India',
#  'Mumbai, Maharashtra 400610, India',
#  'B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 400605, India',
#  'Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, Maharashtra 400607, India',
#  'Dadlani Park, Raheja Complex, Majiwada, Thane, Maharashtra 400608, India',
#  'LE ROUGE TRENDZ PVT.LTD.Ground Floor,Rounak Business Centre,Opp.Cine, Wonder,Nex, Thane, Maharashtra 400607, India']

# %% [markdown]
# Looking good. Let's now place all this into a Pandas dataframe.

# %%
import pandas as pd


df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes, 
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})
df_locations.drop(df_locations.loc[df_locations['Address'] == 'India'].index, inplace = True)
mumbai_loc = df_locations['Address'].tolist()
val = [location for location in mumbai_loc if "Mumbai, Maharashtra" in location]
df_locations.drop(df_locations.loc[df_locations['Address'].isin(val)].index, inplace = True)
df_locations.shape
# Out:
# (73, 6)

# %% [markdown]
# ...and let's now save/persist this data into local file.

# %%
df_locations.to_pickle('./locations.pkl')

# %% [markdown]
# ### Foursquare
# Now that we have our location candidates, let's use Foursquare API to get info on restaurants in each neighborhood.
# We will find neigbourhood which has good access to restaurants, snacks shops, nightlife, gym, shopping.

# %%
# The code was removed by Watson Studio for sharing.
CLIENT_ID = 'OYO0NM5CMICIRICPG2WSKJ1YZ22TY14GD321UBKJ1OCMF2IP'
CLIENT_SECRET = 'FIOIMTDTC4WJNETMWENCBK2E0ESPOWQ2AVSWDF4S1T5QRLHI'
VERSION = '20180605' # Foursquare API version
LIMIT=1000

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Get the amenities for all the neighbourhood

# %%
mumbai_venues = getNearbyVenues(names=df_locations['Address'],
                                   latitudes=df_locations['Latitude'],
                                   longitudes=df_locations['Longitude']
                                  )

# %%
print(mumbai_venues.shape)
mumbai_venues.head(10)
# Out:
# (4636, 7)
#                                       Neighborhood  Neighborhood Latitude  \
# 0  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 1  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 2  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 3  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 4  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 5  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 6  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 7  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 8  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
# 9  Vile Parle East, Vile Parle, Maharashtra, India              19.089736
#
#    Neighborhood Longitude                                      Venue  \
# 0                72.85649          Starbucks Coffee: A Tata Alliance
# 1                72.85649                              Taj Santacruz
# 2                72.85649                                Sahara Star
# 3                72.85649                                     Tarmac
# 4                72.85649                            Mad Over Donuts
# 5                72.85649                        Natural's Ice Cream
# 6                72.85649                                Grand Hyatt
# 7                72.85649                          The Good Food Co.
# 8                72.85649  Chhatrapati Shivaji International Airport
# 9                72.85649                                     Celini
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       19.092329        72.856050         Coffee Shop
# 1       19.092823        72.854601               Hotel
# 2       19.095620        72.853938               Hotel
# 3       19.092039        72.859045             Airport
# 4       19.092992        72.856178          Donut Shop
# 5       19.077560        72.863035      Ice Cream Shop
# 6       19.076832        72.851270               Hotel
# 7       19.098453        72.845769                Café
# 8       19.090509        72.865148             Airport
# 9       19.076831        72.851734  Italian Restaurant

# %% [markdown]
# See, how different amenities for each neighbourhood

# %%
mumbai_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# 1, Narayan Nagar, Mumbra, Thane, Maharashtra 40...                      4
# 1, Pokharan Rd Number 1, Shastri Nagar, Vartak ...                     68
# 10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon...                     32
# 12, Sakharam Lanjekar Road, Parmanand Wadi, Par...                     49
# 184/B, Sant Rohidas Marg, Dharavi koliwada, Dha...                     91
# 1st Floor, St. Lawrence High School 90 Feet Roa...                     90
# 2, HMA Faqir St, The Mahim Makarand CHS, Mahim ...                    100
# 209, Dinshaw Vacha Rd, Churchgate, Maharashtra ...                    100
# 25, Prakash Thorat Marg, Gaikwad nagar, Budha N...                     83
# 329, Subhash Nagar, Mohili, Asalpha, Maharashtr...                     85
# 400060, Sarvodaya Nagar, MHADA Colony, Indira N...                     46
# 400065, Workers Colony, Aarey Colony, Goregaon,...                     14
# 428, KN Gaikwad Marg, Ganesh Nagar, Postal Colo...                     89
# 446, Govind Patil Rd, Patil Pada, Danda Village...                    100
# 515/A, Shankar Ghanekar Rd, Three View Co-Opera...                    100
# 703, Bhardawadi Rd, ICICI Colony, Amboli, Andhe...                     68
# 802, B3, MM Valley, Nr TMC Stadium, Jilani Park...                      4
# A Hill Crest, Holy cross Road I.C.Colony, near ...                     75
# A-402, Krishna Vatika Marg, Snehadham, Azad Nag...                     45
# Anant Niwas Rana Nagar No. 1, Reti Bunder Road,...                      7
# Andheri - Kurla Rd, Jarimari, Saki Naka, Mahara...                    100
# B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Ma...                    100
# B/23, Highway Apartment., 2nd floor., Eastern E...                     52
# B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 4...                     11
# Bandra - Worli Sea Link, Mount Mary, Bandra Wes...                     39
# Bdb Gate 1, G Block BKC, Bandra Kurla Complex, ...                     84
# Bunglow no. 786, Aqsa Masjid Rd, Behind Medow P...                    100
# C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, V...                    100
# C-46, LBS Rd, Godrej & Boyce Industry Estate, V...                     87
# Casa Bella Magnifica Bus Stop, Casa Bella Main ...                      4
# ...                                                                   ...
# Lower Parel, Lower Parel Bridge, Lower Parel, M...                    100
# Lucky Towers, MG Cross Rd Number 4, Amrut Nagar...                     91
# Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Sa...                    100
# Maroshi Naka, Unit 25, Aarey Colony, Goregaon, ...                     40
# National Park - BMC Colony Rd, Maharashtra 4001...                     42
# Navpada, Chhatrapati Shivaji International Airp...                    100
# New Dock Rd, Victoria Docks Port Trust, Mazgaon...                     14
# P and T Colony Rd, P and T Colony, Chhatrapati ...                     56
# PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maha...                     72
# Premier Colony, Kurla West, Maharashtra 400070,...                    100
# Rolex Apartment, Underai Rd, Malad, Navy Colony...                    100
# Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Cha...                     71
# Room no 645 rajive gandhi nagar Near New Transi...                     90
# Rushi Van Borivali, Rushi Van, Next to Kajupada...                     14
# Saket - Kalwa Rd, Rabodi, Thane West, Thane, Ma...                     88
# Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar,...                    100
# Shiv Shakti Shopping Complex, Deepak Kumar Marg...                     86
# Shop No. 1, Ground Floor, Vallabh Vihar, Opp. K...                    100
# Shop Number.21 A Wing Kamaraj CHS Near JPR Radi...                    100
# Shri Ganesh Rahivasi Seva Sangh, Khale Compound...                    100
# Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, ...                     45
# Unnamed Road, Anjur, Maharashtra 421302, India                          7
# Unnamed Road, Domkhar Gaon, Thane, Maharashtra ...                      5
# Unnamed Road, Fort, Maharashtra 400001, India                         100
# Unnamed Road, Malad, Shivaji Nagar, Kurar Villa...                     69
# Unnamed Road, Pereira Wadi, Asalpha, Maharashtr...                     77
# Unnamed Road, Pratiksha Nagar, BPCL Terminal, W...                      9
# Vile Parle East, Vile Parle, Maharashtra, India                        88
# garden grove, b-1, flat no. 1301, b-wing, chiku...                     98
# pollution response team Near mazagon Dock, Maha...                     29
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# 1, Narayan Nagar, Mumbra, Thane, Maharashtra 40...                       4
# 1, Pokharan Rd Number 1, Shastri Nagar, Vartak ...                      68
# 10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon...                      32
# 12, Sakharam Lanjekar Road, Parmanand Wadi, Par...                      49
# 184/B, Sant Rohidas Marg, Dharavi koliwada, Dha...                      91
# 1st Floor, St. Lawrence High School 90 Feet Roa...                      90
# 2, HMA Faqir St, The Mahim Makarand CHS, Mahim ...                     100
# 209, Dinshaw Vacha Rd, Churchgate, Maharashtra ...                     100
# 25, Prakash Thorat Marg, Gaikwad nagar, Budha N...                      83
# 329, Subhash Nagar, Mohili, Asalpha, Maharashtr...                      85
# 400060, Sarvodaya Nagar, MHADA Colony, Indira N...                      46
# 400065, Workers Colony, Aarey Colony, Goregaon,...                      14
# 428, KN Gaikwad Marg, Ganesh Nagar, Postal Colo...                      89
# 446, Govind Patil Rd, Patil Pada, Danda Village...                     100
# 515/A, Shankar Ghanekar Rd, Three View Co-Opera...                     100
# 703, Bhardawadi Rd, ICICI Colony, Amboli, Andhe...                      68
# 802, B3, MM Valley, Nr TMC Stadium, Jilani Park...                       4
# A Hill Crest, Holy cross Road I.C.Colony, near ...                      75
# A-402, Krishna Vatika Marg, Snehadham, Azad Nag...                      45
# Anant Niwas Rana Nagar No. 1, Reti Bunder Road,...                       7
# Andheri - Kurla Rd, Jarimari, Saki Naka, Mahara...                     100
# B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Ma...                     100
# B/23, Highway Apartment., 2nd floor., Eastern E...                      52
# B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 4...                      11
# Bandra - Worli Sea Link, Mount Mary, Bandra Wes...                      39
# Bdb Gate 1, G Block BKC, Bandra Kurla Complex, ...                      84
# Bunglow no. 786, Aqsa Masjid Rd, Behind Medow P...                     100
# C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, V...                     100
# C-46, LBS Rd, Godrej & Boyce Industry Estate, V...                      87
# Casa Bella Magnifica Bus Stop, Casa Bella Main ...                       4
# ...                                                                    ...
# Lower Parel, Lower Parel Bridge, Lower Parel, M...                     100
# Lucky Towers, MG Cross Rd Number 4, Amrut Nagar...                      91
# Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Sa...                     100
# Maroshi Naka, Unit 25, Aarey Colony, Goregaon, ...                      40
# National Park - BMC Colony Rd, Maharashtra 4001...                      42
# Navpada, Chhatrapati Shivaji International Airp...                     100
# New Dock Rd, Victoria Docks Port Trust, Mazgaon...                      14
# P and T Colony Rd, P and T Colony, Chhatrapati ...                      56
# PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maha...                      72
# Premier Colony, Kurla West, Maharashtra 400070,...                     100
# Rolex Apartment, Underai Rd, Malad, Navy Colony...                     100
# Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Cha...                      71
# Room no 645 rajive gandhi nagar Near New Transi...                      90
# Rushi Van Borivali, Rushi Van, Next to Kajupada...                      14
# Saket - Kalwa Rd, Rabodi, Thane West, Thane, Ma...                      88
# Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar,...                     100
# Shiv Shakti Shopping Complex, Deepak Kumar Marg...                      86
# Shop No. 1, Ground Floor, Vallabh Vihar, Opp. K...                     100
# Shop Number.21 A Wing Kamaraj CHS Near JPR Radi...                     100
# Shri Ganesh Rahivasi Seva Sangh, Khale Compound...                     100
# Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, ...                      45
# Unnamed Road, Anjur, Maharashtra 421302, India                           7
# Unnamed Road, Domkhar Gaon, Thane, Maharashtra ...                       5
# Unnamed Road, Fort, Maharashtra 400001, India                          100
# Unnamed Road, Malad, Shivaji Nagar, Kurar Villa...                      69
# Unnamed Road, Pereira Wadi, Asalpha, Maharashtr...                      77
# Unnamed Road, Pratiksha Nagar, BPCL Terminal, W...                       9
# Vile Parle East, Vile Parle, Maharashtra, India                         88
# garden grove, b-1, flat no. 1301, b-wing, chiku...                      98
# pollution response team Near mazagon Dock, Maha...                      29
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# 1, Narayan Nagar, Mumbra, Thane, Maharashtra 40...      4               4
# 1, Pokharan Rd Number 1, Shastri Nagar, Vartak ...     68              68
# 10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon...     32              32
# 12, Sakharam Lanjekar Road, Parmanand Wadi, Par...     49              49
# 184/B, Sant Rohidas Marg, Dharavi koliwada, Dha...     91              91
# 1st Floor, St. Lawrence High School 90 Feet Roa...     90              90
# 2, HMA Faqir St, The Mahim Makarand CHS, Mahim ...    100             100
# 209, Dinshaw Vacha Rd, Churchgate, Maharashtra ...    100             100
# 25, Prakash Thorat Marg, Gaikwad nagar, Budha N...     83              83
# 329, Subhash Nagar, Mohili, Asalpha, Maharashtr...     85              85
# 400060, Sarvodaya Nagar, MHADA Colony, Indira N...     46              46
# 400065, Workers Colony, Aarey Colony, Goregaon,...     14              14
# 428, KN Gaikwad Marg, Ganesh Nagar, Postal Colo...     89              89
# 446, Govind Patil Rd, Patil Pada, Danda Village...    100             100
# 515/A, Shankar Ghanekar Rd, Three View Co-Opera...    100             100
# 703, Bhardawadi Rd, ICICI Colony, Amboli, Andhe...     68              68
# 802, B3, MM Valley, Nr TMC Stadium, Jilani Park...      4               4
# A Hill Crest, Holy cross Road I.C.Colony, near ...     75              75
# A-402, Krishna Vatika Marg, Snehadham, Azad Nag...     45              45
# Anant Niwas Rana Nagar No. 1, Reti Bunder Road,...      7               7
# Andheri - Kurla Rd, Jarimari, Saki Naka, Mahara...    100             100
# B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Ma...    100             100
# B/23, Highway Apartment., 2nd floor., Eastern E...     52              52
# B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 4...     11              11
# Bandra - Worli Sea Link, Mount Mary, Bandra Wes...     39              39
# Bdb Gate 1, G Block BKC, Bandra Kurla Complex, ...     84              84
# Bunglow no. 786, Aqsa Masjid Rd, Behind Medow P...    100             100
# C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, V...    100             100
# C-46, LBS Rd, Godrej & Boyce Industry Estate, V...     87              87
# Casa Bella Magnifica Bus Stop, Casa Bella Main ...      4               4
# ...                                                   ...             ...
# Lower Parel, Lower Parel Bridge, Lower Parel, M...    100             100
# Lucky Towers, MG Cross Rd Number 4, Amrut Nagar...     91              91
# Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Sa...    100             100
# Maroshi Naka, Unit 25, Aarey Colony, Goregaon, ...     40              40
# National Park - BMC Colony Rd, Maharashtra 4001...     42              42
# Navpada, Chhatrapati Shivaji International Airp...    100             100
# New Dock Rd, Victoria Docks Port Trust, Mazgaon...     14              14
# P and T Colony Rd, P and T Colony, Chhatrapati ...     56              56
# PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maha...     72              72
# Premier Colony, Kurla West, Maharashtra 400070,...    100             100
# Rolex Apartment, Underai Rd, Malad, Navy Colony...    100             100
# Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Cha...     71              71
# Room no 645 rajive gandhi nagar Near New Transi...     90              90
# Rushi Van Borivali, Rushi Van, Next to Kajupada...     14              14
# Saket - Kalwa Rd, Rabodi, Thane West, Thane, Ma...     88              88
# Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar,...    100             100
# Shiv Shakti Shopping Complex, Deepak Kumar Marg...     86              86
# Shop No. 1, Ground Floor, Vallabh Vihar, Opp. K...    100             100
# Shop Number.21 A Wing Kamaraj CHS Near JPR Radi...    100             100
# Shri Ganesh Rahivasi Seva Sangh, Khale Compound...    100             100
# Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, ...     45              45
# Unnamed Road, Anjur, Maharashtra 421302, India          7               7
# Unnamed Road, Domkhar Gaon, Thane, Maharashtra ...      5               5
# Unnamed Road, Fort, Maharashtra 400001, India         100             100
# Unnamed Road, Malad, Shivaji Nagar, Kurar Villa...     69              69
# Unnamed Road, Pereira Wadi, Asalpha, Maharashtr...     77              77
# Unnamed Road, Pratiksha Nagar, BPCL Terminal, W...      9               9
# Vile Parle East, Vile Parle, Maharashtra, India        88              88
# garden grove, b-1, flat no. 1301, b-wing, chiku...     98              98
# pollution response team Near mazagon Dock, Maha...     29              29
#
#                                                     Venue Longitude  \
# Neighborhood
# 1, Narayan Nagar, Mumbra, Thane, Maharashtra 40...                4
# 1, Pokharan Rd Number 1, Shastri Nagar, Vartak ...               68
# 10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon...               32
# 12, Sakharam Lanjekar Road, Parmanand Wadi, Par...               49
# 184/B, Sant Rohidas Marg, Dharavi koliwada, Dha...               91
# 1st Floor, St. Lawrence High School 90 Feet Roa...               90
# 2, HMA Faqir St, The Mahim Makarand CHS, Mahim ...              100
# 209, Dinshaw Vacha Rd, Churchgate, Maharashtra ...              100
# 25, Prakash Thorat Marg, Gaikwad nagar, Budha N...               83
# 329, Subhash Nagar, Mohili, Asalpha, Maharashtr...               85
# 400060, Sarvodaya Nagar, MHADA Colony, Indira N...               46
# 400065, Workers Colony, Aarey Colony, Goregaon,...               14
# 428, KN Gaikwad Marg, Ganesh Nagar, Postal Colo...               89
# 446, Govind Patil Rd, Patil Pada, Danda Village...              100
# 515/A, Shankar Ghanekar Rd, Three View Co-Opera...              100
# 703, Bhardawadi Rd, ICICI Colony, Amboli, Andhe...               68
# 802, B3, MM Valley, Nr TMC Stadium, Jilani Park...                4
# A Hill Crest, Holy cross Road I.C.Colony, near ...               75
# A-402, Krishna Vatika Marg, Snehadham, Azad Nag...               45
# Anant Niwas Rana Nagar No. 1, Reti Bunder Road,...                7
# Andheri - Kurla Rd, Jarimari, Saki Naka, Mahara...              100
# B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Ma...              100
# B/23, Highway Apartment., 2nd floor., Eastern E...               52
# B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 4...               11
# Bandra - Worli Sea Link, Mount Mary, Bandra Wes...               39
# Bdb Gate 1, G Block BKC, Bandra Kurla Complex, ...               84
# Bunglow no. 786, Aqsa Masjid Rd, Behind Medow P...              100
# C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, V...              100
# C-46, LBS Rd, Godrej & Boyce Industry Estate, V...               87
# Casa Bella Magnifica Bus Stop, Casa Bella Main ...                4
# ...                                                             ...
# Lower Parel, Lower Parel Bridge, Lower Parel, M...              100
# Lucky Towers, MG Cross Rd Number 4, Amrut Nagar...               91
# Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Sa...              100
# Maroshi Naka, Unit 25, Aarey Colony, Goregaon, ...               40
# National Park - BMC Colony Rd, Maharashtra 4001...               42
# Navpada, Chhatrapati Shivaji International Airp...              100
# New Dock Rd, Victoria Docks Port Trust, Mazgaon...               14
# P and T Colony Rd, P and T Colony, Chhatrapati ...               56
# PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maha...               72
# Premier Colony, Kurla West, Maharashtra 400070,...              100
# Rolex Apartment, Underai Rd, Malad, Navy Colony...              100
# Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Cha...               71
# Room no 645 rajive gandhi nagar Near New Transi...               90
# Rushi Van Borivali, Rushi Van, Next to Kajupada...               14
# Saket - Kalwa Rd, Rabodi, Thane West, Thane, Ma...               88
# Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar,...              100
# Shiv Shakti Shopping Complex, Deepak Kumar Marg...               86
# Shop No. 1, Ground Floor, Vallabh Vihar, Opp. K...              100
# Shop Number.21 A Wing Kamaraj CHS Near JPR Radi...              100
# Shri Ganesh Rahivasi Seva Sangh, Khale Compound...              100
# Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, ...               45
# Unnamed Road, Anjur, Maharashtra 421302, India                    7
# Unnamed Road, Domkhar Gaon, Thane, Maharashtra ...                5
# Unnamed Road, Fort, Maharashtra 400001, India                   100
# Unnamed Road, Malad, Shivaji Nagar, Kurar Villa...               69
# Unnamed Road, Pereira Wadi, Asalpha, Maharashtr...               77
# Unnamed Road, Pratiksha Nagar, BPCL Terminal, W...                9
# Vile Parle East, Vile Parle, Maharashtra, India                  88
# garden grove, b-1, flat no. 1301, b-wing, chiku...               98
# pollution response team Near mazagon Dock, Maha...               29
#
#                                                     Venue Category
# Neighborhood
# 1, Narayan Nagar, Mumbra, Thane, Maharashtra 40...               4
# 1, Pokharan Rd Number 1, Shastri Nagar, Vartak ...              68
# 10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon...              32
# 12, Sakharam Lanjekar Road, Parmanand Wadi, Par...              49
# 184/B, Sant Rohidas Marg, Dharavi koliwada, Dha...              91
# 1st Floor, St. Lawrence High School 90 Feet Roa...              90
# 2, HMA Faqir St, The Mahim Makarand CHS, Mahim ...             100
# 209, Dinshaw Vacha Rd, Churchgate, Maharashtra ...             100
# 25, Prakash Thorat Marg, Gaikwad nagar, Budha N...              83
# 329, Subhash Nagar, Mohili, Asalpha, Maharashtr...              85
# 400060, Sarvodaya Nagar, MHADA Colony, Indira N...              46
# 400065, Workers Colony, Aarey Colony, Goregaon,...              14
# 428, KN Gaikwad Marg, Ganesh Nagar, Postal Colo...              89
# 446, Govind Patil Rd, Patil Pada, Danda Village...             100
# 515/A, Shankar Ghanekar Rd, Three View Co-Opera...             100
# 703, Bhardawadi Rd, ICICI Colony, Amboli, Andhe...              68
# 802, B3, MM Valley, Nr TMC Stadium, Jilani Park...               4
# A Hill Crest, Holy cross Road I.C.Colony, near ...              75
# A-402, Krishna Vatika Marg, Snehadham, Azad Nag...              45
# Anant Niwas Rana Nagar No. 1, Reti Bunder Road,...               7
# Andheri - Kurla Rd, Jarimari, Saki Naka, Mahara...             100
# B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Ma...             100
# B/23, Highway Apartment., 2nd floor., Eastern E...              52
# B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 4...              11
# Bandra - Worli Sea Link, Mount Mary, Bandra Wes...              39
# Bdb Gate 1, G Block BKC, Bandra Kurla Complex, ...              84
# Bunglow no. 786, Aqsa Masjid Rd, Behind Medow P...             100
# C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, V...             100
# C-46, LBS Rd, Godrej & Boyce Industry Estate, V...              87
# Casa Bella Magnifica Bus Stop, Casa Bella Main ...               4
# ...                                                            ...
# Lower Parel, Lower Parel Bridge, Lower Parel, M...             100
# Lucky Towers, MG Cross Rd Number 4, Amrut Nagar...              91
# Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Sa...             100
# Maroshi Naka, Unit 25, Aarey Colony, Goregaon, ...              40
# National Park - BMC Colony Rd, Maharashtra 4001...              42
# Navpada, Chhatrapati Shivaji International Airp...             100
# New Dock Rd, Victoria Docks Port Trust, Mazgaon...              14
# P and T Colony Rd, P and T Colony, Chhatrapati ...              56
# PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maha...              72
# Premier Colony, Kurla West, Maharashtra 400070,...             100
# Rolex Apartment, Underai Rd, Malad, Navy Colony...             100
# Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Cha...              71
# Room no 645 rajive gandhi nagar Near New Transi...              90
# Rushi Van Borivali, Rushi Van, Next to Kajupada...              14
# Saket - Kalwa Rd, Rabodi, Thane West, Thane, Ma...              88
# Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar,...             100
# Shiv Shakti Shopping Complex, Deepak Kumar Marg...              86
# Shop No. 1, Ground Floor, Vallabh Vihar, Opp. K...             100
# Shop Number.21 A Wing Kamaraj CHS Near JPR Radi...             100
# Shri Ganesh Rahivasi Seva Sangh, Khale Compound...             100
# Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, ...              45
# Unnamed Road, Anjur, Maharashtra 421302, India                   7
# Unnamed Road, Domkhar Gaon, Thane, Maharashtra ...               5
# Unnamed Road, Fort, Maharashtra 400001, India                  100
# Unnamed Road, Malad, Shivaji Nagar, Kurar Villa...              69
# Unnamed Road, Pereira Wadi, Asalpha, Maharashtr...              77
# Unnamed Road, Pratiksha Nagar, BPCL Terminal, W...               9
# Vile Parle East, Vile Parle, Maharashtra, India                 88
# garden grove, b-1, flat no. 1301, b-wing, chiku...              98
# pollution response team Near mazagon Dock, Maha...              29
#
# [72 rows x 6 columns]

# %% [markdown]
# There are multiple categories for each amenity, lets merge them for convinience

# %%
print('There are {} uniques categories.'.format(len(mumbai_venues['Venue Category'].unique())))
temp = mumbai_venues['Venue Category'].unique()
resto = 'Restaurant'
gym = 'Gym'
snacks = ['Coffee Shop', 'Café', 'Ice Cream Shop', 'Dessert Shop', 'Bakery', 'Salad Place', 'Cupcake Shop', 'Snack Place', 
          'Pizza Place', 'Bagel Shop', 'Irani Cafe', 'Donut Shop', 'Food & Drink Shop', 'Food Court', 'Bed & Breakfast', 
          'Tea Room', 'Fried Chicken Joint', 'Frozen Yogurt Shop', 'Food', 'Burger Joint', 'Burrito Place', 'Chaat Place', 
          'Noodle House', 'Sandwich Place', 'Breakfast Spot', 'Deli / Bodega', 'Juice Bar', 'Cafeteria', 'Bistro']
Night_life = ['Hotel', 'Bar', 'Lounge', 'Cocktail Bar', 'Beer Garden', 'BBQ Joint', 'Diner', 'Hotel Bar', 'Whisky Bar',
              'Beer Bar', 'Dhaba', 'Buffet', 'Wine Bar', 'Nightclub', 'Gastropub', 'Steakhouse', 'Hookah Bar', 'Pub']
Shopping = ["Women's Store", 'Toy / Game Store', 'Clothing Store', 'Grocery Store', 
            'Movie Theater', 'Convenience Store', 'Food Truck', 'Shopping Mall', 'Camera Store',
            'Electronics Store', 'Department Store', 'Gift Shop', 'Flea Market', 'Market', 'Jewelry Store',
            'Cheese Shop', "Men's Store", 'Flower Shop',  'Supermarket', 'Sporting Goods Shop']

res = []
exp = []
snacks_type = []
night_life_type = []
shopping_type =[]
gym_type = []
for i in temp:
    if(resto in i):
        res.append(i)
    elif(i in snacks):
        snacks_type.append(i)
    elif(i in Night_life):
        night_life_type.append(i)
    elif(i in Shopping):
        shopping_type.append(i)
    elif(gym in i):
        gym_type.append(i)
    else:
        exp.append(i)
# Out:
# There are 222 uniques categories.

# %% [markdown]
# Merge the cell as per category

# %%
def addition(a, num):
    val = []
    for i in range(0, num):
        temp = 0
        for j in a:
            temp = temp + mumbai_onehot[j][i]
        val.append(temp)
    return(val)        
        

# one hot encoding
mumbai_onehot = pd.get_dummies(mumbai_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
mumbai_onehot['Neighborhood'] = mumbai_venues['Neighborhood']
mumbai_onehot.columns.get_loc("Neighborhood")
# move neighborhood column to the first column
fixed_columns = [mumbai_onehot.columns[116]] + list(mumbai_onehot.columns[:116]) + list(mumbai_onehot.columns[117:])
mumbai_onehot = mumbai_onehot[fixed_columns]
print(mumbai_onehot.shape)
mumbai_onehot['All Restaurant'] = addition(res, 4636)
mumbai_onehot['Snacks'] = addition(snacks_type, 4636)
mumbai_onehot['Night life'] = addition(night_life_type, 4636)
mumbai_onehot['Shopping'] = addition(shopping_type, 4636)
mumbai_onehot['All_Gym'] = addition(gym_type, 4636)
mumbai_onehot.drop(res + snacks_type + night_life_type + shopping_type + gym_type, axis = 1, inplace = True)
print(mumbai_onehot.shape)
# Out:
# (4636, 222)
# (4636, 113)

# %%
mumbai_grouped = mumbai_onehot.groupby('Neighborhood').mean().reset_index()
mumbai_grouped
# Out:
#                                          Neighborhood   ATM  \
# 0   1, Narayan Nagar, Mumbra, Thane, Maharashtra 4...  0.00
# 1   1, Pokharan Rd Number 1, Shastri Nagar, Vartak...  0.00
# 2   10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregao...  0.00
# 3   12, Sakharam Lanjekar Road, Parmanand Wadi, Pa...  0.00
# 4   184/B, Sant Rohidas Marg, Dharavi koliwada, Dh...  0.00
# 5   1st Floor, St. Lawrence High School 90 Feet Ro...  0.00
# 6   2, HMA Faqir St, The Mahim Makarand CHS, Mahim...  0.00
# 7   209, Dinshaw Vacha Rd, Churchgate, Maharashtra...  0.00
# 8   25, Prakash Thorat Marg, Gaikwad nagar, Budha ...  0.00
# 9   329, Subhash Nagar, Mohili, Asalpha, Maharasht...  0.00
# 10  400060, Sarvodaya Nagar, MHADA Colony, Indira ...  0.00
# 11  400065, Workers Colony, Aarey Colony, Goregaon...  0.00
# 12  428, KN Gaikwad Marg, Ganesh Nagar, Postal Col...  0.00
# 13  446, Govind Patil Rd, Patil Pada, Danda Villag...  0.00
# 14  515/A, Shankar Ghanekar Rd, Three View Co-Oper...  0.00
# 15  703, Bhardawadi Rd, ICICI Colony, Amboli, Andh...  0.00
# 16  802, B3, MM Valley, Nr TMC Stadium, Jilani Par...  0.25
# 17  A Hill Crest, Holy cross Road I.C.Colony, near...  0.00
# 18  A-402, Krishna Vatika Marg, Snehadham, Azad Na...  0.00
# 19  Anant Niwas Rana Nagar No. 1, Reti Bunder Road...  0.00
# 20  Andheri - Kurla Rd, Jarimari, Saki Naka, Mahar...  0.00
# 21  B-21, Bhatwadi, Barve Nagar, Ghatkopar West, M...  0.00
# 22  B/23, Highway Apartment., 2nd floor., Eastern ...  0.00
# 23  B5-WING, Kharegaon, Kalwa, Thane, Maharashtra ...  0.00
# 24  Bandra - Worli Sea Link, Mount Mary, Bandra We...  0.00
# 25  Bdb Gate 1, G Block BKC, Bandra Kurla Complex,...  0.00
# 26  Bunglow no. 786, Aqsa Masjid Rd, Behind Medow ...  0.00
# 27  C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, ...  0.00
# 28  C-46, LBS Rd, Godrej & Boyce Industry Estate, ...  0.00
# 29  Casa Bella Magnifica Bus Stop, Casa Bella Main...  0.00
# ..                                                ...   ...
# 42  Lower Parel, Lower Parel Bridge, Lower Parel, ...  0.00
# 43  Lucky Towers, MG Cross Rd Number 4, Amrut Naga...  0.00
# 44  Mangal Prabha, Prabhat Colony Rd, Sen Nagar, S...  0.00
# 45  Maroshi Naka, Unit 25, Aarey Colony, Goregaon,...  0.00
# 46  National Park - BMC Colony Rd, Maharashtra 400...  0.00
# 47  Navpada, Chhatrapati Shivaji International Air...  0.00
# 48  New Dock Rd, Victoria Docks Port Trust, Mazgao...  0.00
# 49  P and T Colony Rd, P and T Colony, Chhatrapati...  0.00
# 50  PL Lokhande Marg, ACC Nagar, Chedda Nagar, Mah...  0.00
# 51  Premier Colony, Kurla West, Maharashtra 400070...  0.00
# 52  Rolex Apartment, Underai Rd, Malad, Navy Colon...  0.00
# 53  Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Ch...  0.00
# 54  Room no 645 rajive gandhi nagar Near New Trans...  0.00
# 55  Rushi Van Borivali, Rushi Van, Next to Kajupad...  0.00
# 56  Saket - Kalwa Rd, Rabodi, Thane West, Thane, M...  0.00
# 57  Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar...  0.00
# 58  Shiv Shakti Shopping Complex, Deepak Kumar Mar...  0.00
# 59  Shop No. 1, Ground Floor, Vallabh Vihar, Opp. ...  0.00
# 60  Shop Number.21 A Wing Kamaraj CHS Near JPR Rad...  0.00
# 61  Shri Ganesh Rahivasi Seva Sangh, Khale Compoun...  0.00
# 62  Tikuji Ni Wadi Rd, Manpada, Thane West, Thane,...  0.00
# 63     Unnamed Road, Anjur, Maharashtra 421302, India  0.00
# 64  Unnamed Road, Domkhar Gaon, Thane, Maharashtra...  0.00
# 65      Unnamed Road, Fort, Maharashtra 400001, India  0.00
# 66  Unnamed Road, Malad, Shivaji Nagar, Kurar Vill...  0.00
# 67  Unnamed Road, Pereira Wadi, Asalpha, Maharasht...  0.00
# 68  Unnamed Road, Pratiksha Nagar, BPCL Terminal, ...  0.00
# 69    Vile Parle East, Vile Parle, Maharashtra, India  0.00
# 70  garden grove, b-1, flat no. 1301, b-wing, chik...  0.00
# 71  pollution response team Near mazagon Dock, Mah...  0.00
#
#     Accessories Store   Airport  Airport Lounge  Airport Service  \
# 0            0.000000  0.000000        0.000000             0.00
# 1            0.000000  0.000000        0.000000             0.00
# 2            0.000000  0.000000        0.000000             0.00
# 3            0.000000  0.000000        0.000000             0.00
# 4            0.000000  0.000000        0.000000             0.00
# 5            0.000000  0.000000        0.000000             0.00
# 6            0.000000  0.000000        0.000000             0.00
# 7            0.000000  0.000000        0.000000             0.00
# 8            0.000000  0.000000        0.000000             0.00
# 9            0.000000  0.000000        0.000000             0.00
# 10           0.000000  0.000000        0.000000             0.00
# 11           0.000000  0.000000        0.000000             0.00
# 12           0.000000  0.000000        0.000000             0.00
# 13           0.000000  0.000000        0.000000             0.00
# 14           0.000000  0.000000        0.000000             0.00
# 15           0.014706  0.000000        0.000000             0.00
# 16           0.000000  0.000000        0.000000             0.00
# 17           0.000000  0.000000        0.000000             0.00
# 18           0.000000  0.000000        0.000000             0.00
# 19           0.000000  0.000000        0.000000             0.00
# 20           0.000000  0.010000        0.010000             0.03
# 21           0.000000  0.000000        0.000000             0.00
# 22           0.000000  0.000000        0.000000             0.00
# 23           0.000000  0.000000        0.000000             0.00
# 24           0.000000  0.000000        0.000000             0.00
# 25           0.000000  0.000000        0.000000             0.00
# 26           0.000000  0.000000        0.000000             0.00
# 27           0.000000  0.010000        0.000000             0.00
# 28           0.000000  0.000000        0.000000             0.00
# 29           0.000000  0.000000        0.000000             0.00
# ..                ...       ...             ...              ...
# 42           0.000000  0.000000        0.000000             0.00
# 43           0.000000  0.000000        0.000000             0.00
# 44           0.000000  0.010000        0.000000             0.00
# 45           0.000000  0.000000        0.000000             0.00
# 46           0.000000  0.000000        0.000000             0.00
# 47           0.000000  0.020000        0.010000             0.02
# 48           0.000000  0.000000        0.000000             0.00
# 49           0.000000  0.035714        0.017857             0.00
# 50           0.000000  0.000000        0.000000             0.00
# 51           0.000000  0.000000        0.000000             0.00
# 52           0.000000  0.000000        0.000000             0.00
# 53           0.000000  0.000000        0.000000             0.00
# 54           0.000000  0.000000        0.000000             0.00
# 55           0.000000  0.000000        0.000000             0.00
# 56           0.000000  0.000000        0.000000             0.00
# 57           0.000000  0.000000        0.000000             0.00
# 58           0.000000  0.000000        0.000000             0.00
# 59           0.000000  0.000000        0.000000             0.00
# 60           0.000000  0.000000        0.000000             0.00
# 61           0.000000  0.000000        0.000000             0.00
# 62           0.000000  0.000000        0.000000             0.00
# 63           0.000000  0.000000        0.000000             0.00
# 64           0.000000  0.000000        0.000000             0.00
# 65           0.000000  0.000000        0.000000             0.00
# 66           0.000000  0.000000        0.000000             0.00
# 67           0.012987  0.000000        0.000000             0.00
# 68           0.000000  0.000000        0.000000             0.00
# 69           0.000000  0.022727        0.011364             0.00
# 70           0.000000  0.000000        0.000000             0.00
# 71           0.000000  0.000000        0.000000             0.00
#
#     Airport Terminal  Antique Shop    Arcade  Art Gallery  ...     Track  \
# 0           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 1           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 2           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 3           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 4           0.000000          0.00  0.010989     0.000000  ...  0.000000
# 5           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 6           0.000000          0.00  0.010000     0.000000  ...  0.010000
# 7           0.000000          0.00  0.000000     0.010000  ...  0.000000
# 8           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 9           0.000000          0.00  0.000000     0.000000  ...  0.000000
# 10          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 11          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 12          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 13          0.000000          0.00  0.020000     0.000000  ...  0.000000
# 14          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 15          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 16          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 17          0.000000          0.00  0.013333     0.000000  ...  0.000000
# 18          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 19          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 20          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 21          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 22          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 23          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 24          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 25          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 26          0.000000          0.00  0.000000     0.000000  ...  0.010000
# 27          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 28          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 29          0.000000          0.00  0.000000     0.000000  ...  0.000000
# ..               ...           ...       ...          ...  ...       ...
# 42          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 43          0.000000          0.00  0.000000     0.010989  ...  0.000000
# 44          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 45          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 46          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 47          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 48          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 49          0.017857          0.00  0.000000     0.000000  ...  0.000000
# 50          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 51          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 52          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 53          0.000000          0.00  0.014085     0.000000  ...  0.014085
# 54          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 55          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 56          0.000000          0.00  0.000000     0.011364  ...  0.000000
# 57          0.000000          0.01  0.010000     0.000000  ...  0.000000
# 58          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 59          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 60          0.000000          0.00  0.010000     0.000000  ...  0.000000
# 61          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 62          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 63          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 64          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 65          0.000000          0.00  0.000000     0.010000  ...  0.000000
# 66          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 67          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 68          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 69          0.000000          0.00  0.000000     0.000000  ...  0.000000
# 70          0.000000          0.00  0.010204     0.010204  ...  0.000000
# 71          0.000000          0.00  0.000000     0.000000  ...  0.000000
#
#        Trail     Train  Train Station  Water Park  All Restaurant    Snacks  \
# 0   0.000000  0.000000       0.250000    0.000000        0.500000  0.250000
# 1   0.000000  0.000000       0.000000    0.000000        0.397059  0.235294
# 2   0.000000  0.000000       0.000000    0.000000        0.343750  0.281250
# 3   0.000000  0.000000       0.040816    0.000000        0.306122  0.408163
# 4   0.000000  0.010989       0.032967    0.000000        0.483516  0.219780
# 5   0.000000  0.000000       0.011111    0.000000        0.266667  0.300000
# 6   0.000000  0.000000       0.000000    0.000000        0.330000  0.360000
# 7   0.000000  0.000000       0.010000    0.000000        0.330000  0.260000
# 8   0.000000  0.000000       0.000000    0.000000        0.409639  0.265060
# 9   0.000000  0.000000       0.000000    0.000000        0.388235  0.200000
# 10  0.000000  0.000000       0.000000    0.000000        0.456522  0.217391
# 11  0.000000  0.000000       0.000000    0.000000        0.285714  0.142857
# 12  0.000000  0.000000       0.000000    0.000000        0.404494  0.224719
# 13  0.000000  0.000000       0.000000    0.000000        0.330000  0.340000
# 14  0.000000  0.000000       0.000000    0.000000        0.340000  0.390000
# 15  0.000000  0.000000       0.000000    0.000000        0.382353  0.235294
# 16  0.000000  0.000000       0.000000    0.000000        0.500000  0.250000
# 17  0.000000  0.000000       0.026667    0.000000        0.253333  0.386667
# 18  0.000000  0.000000       0.000000    0.000000        0.288889  0.333333
# 19  0.000000  0.000000       0.000000    0.000000        0.142857  0.428571
# 20  0.000000  0.000000       0.000000    0.000000        0.370000  0.190000
# 21  0.000000  0.000000       0.000000    0.000000        0.370000  0.230000
# 22  0.000000  0.019231       0.038462    0.000000        0.384615  0.211538
# 23  0.000000  0.000000       0.090909    0.000000        0.000000  0.272727
# 24  0.000000  0.000000       0.000000    0.000000        0.282051  0.307692
# 25  0.000000  0.000000       0.011905    0.000000        0.345238  0.309524
# 26  0.000000  0.000000       0.000000    0.000000        0.340000  0.280000
# 27  0.000000  0.000000       0.000000    0.000000        0.320000  0.420000
# 28  0.000000  0.000000       0.000000    0.000000        0.321839  0.275862
# 29  0.000000  0.000000       0.000000    0.000000        0.250000  0.000000
# ..       ...       ...            ...         ...             ...       ...
# 42  0.000000  0.000000       0.000000    0.000000        0.310000  0.280000
# 43  0.000000  0.000000       0.021978    0.000000        0.406593  0.307692
# 44  0.000000  0.000000       0.000000    0.000000        0.240000  0.330000
# 45  0.000000  0.000000       0.000000    0.000000        0.450000  0.200000
# 46  0.000000  0.000000       0.000000    0.000000        0.190476  0.285714
# 47  0.000000  0.000000       0.000000    0.000000        0.380000  0.170000
# 48  0.000000  0.000000       0.000000    0.000000        0.357143  0.071429
# 49  0.000000  0.000000       0.017857    0.000000        0.303571  0.321429
# 50  0.000000  0.000000       0.000000    0.000000        0.402778  0.277778
# 51  0.000000  0.000000       0.000000    0.000000        0.430000  0.230000
# 52  0.000000  0.000000       0.000000    0.000000        0.280000  0.300000
# 53  0.000000  0.000000       0.000000    0.000000        0.394366  0.338028
# 54  0.000000  0.000000       0.033333    0.000000        0.388889  0.311111
# 55  0.000000  0.000000       0.071429    0.000000        0.142857  0.214286
# 56  0.000000  0.000000       0.000000    0.000000        0.318182  0.318182
# 57  0.000000  0.000000       0.010000    0.000000        0.370000  0.320000
# 58  0.000000  0.000000       0.000000    0.000000        0.372093  0.232558
# 59  0.000000  0.000000       0.000000    0.000000        0.440000  0.290000
# 60  0.000000  0.010000       0.040000    0.000000        0.470000  0.270000
# 61  0.000000  0.000000       0.000000    0.000000        0.420000  0.280000
# 62  0.000000  0.000000       0.000000    0.022222        0.333333  0.355556
# 63  0.000000  0.000000       0.285714    0.000000        0.142857  0.000000
# 64  0.000000  0.000000       0.000000    0.000000        0.600000  0.000000
# 65  0.000000  0.000000       0.000000    0.000000        0.340000  0.290000
# 66  0.000000  0.014493       0.000000    0.000000        0.246377  0.391304
# 67  0.000000  0.000000       0.000000    0.000000        0.363636  0.220779
# 68  0.111111  0.000000       0.111111    0.000000        0.000000  0.333333
# 69  0.000000  0.000000       0.022727    0.000000        0.318182  0.306818
# 70  0.000000  0.000000       0.010204    0.010204        0.367347  0.316327
# 71  0.000000  0.000000       0.000000    0.000000        0.344828  0.413793
#
#     Night life  Shopping   All_Gym
# 0     0.000000  0.000000  0.000000
# 1     0.132353  0.132353  0.000000
# 2     0.031250  0.031250  0.000000
# 3     0.081633  0.061224  0.020408
# 4     0.065934  0.043956  0.021978
# 5     0.055556  0.155556  0.033333
# 6     0.110000  0.020000  0.010000
# 7     0.110000  0.050000  0.010000
# 8     0.072289  0.072289  0.048193
# 9     0.152941  0.105882  0.011765
# 10    0.152174  0.000000  0.043478
# 11    0.000000  0.000000  0.071429
# 12    0.067416  0.089888  0.033708
# 13    0.150000  0.070000  0.020000
# 14    0.100000  0.070000  0.010000
# 15    0.147059  0.073529  0.044118
# 16    0.000000  0.000000  0.000000
# 17    0.093333  0.053333  0.080000
# 18    0.088889  0.066667  0.066667
# 19    0.000000  0.000000  0.000000
# 20    0.240000  0.050000  0.000000
# 21    0.160000  0.120000  0.020000
# 22    0.115385  0.019231  0.038462
# 23    0.000000  0.181818  0.000000
# 24    0.153846  0.051282  0.025641
# 25    0.142857  0.035714  0.023810
# 26    0.150000  0.060000  0.090000
# 27    0.160000  0.060000  0.000000
# 28    0.160920  0.091954  0.011494
# 29    0.000000  0.250000  0.250000
# ..         ...       ...       ...
# 42    0.160000  0.070000  0.010000
# 43    0.054945  0.098901  0.010989
# 44    0.240000  0.100000  0.040000
# 45    0.175000  0.000000  0.075000
# 46    0.119048  0.142857  0.047619
# 47    0.260000  0.050000  0.000000
# 48    0.142857  0.142857  0.000000
# 49    0.196429  0.017857  0.017857
# 50    0.083333  0.069444  0.055556
# 51    0.120000  0.120000  0.030000
# 52    0.120000  0.150000  0.030000
# 53    0.070423  0.056338  0.028169
# 54    0.033333  0.111111  0.033333
# 55    0.142857  0.071429  0.071429
# 56    0.102273  0.090909  0.000000
# 57    0.080000  0.080000  0.000000
# 58    0.069767  0.093023  0.034884
# 59    0.100000  0.100000  0.020000
# 60    0.040000  0.080000  0.020000
# 61    0.110000  0.090000  0.010000
# 62    0.088889  0.088889  0.022222
# 63    0.000000  0.142857  0.000000
# 64    0.000000  0.000000  0.200000
# 65    0.160000  0.060000  0.010000
# 66    0.028986  0.159420  0.043478
# 67    0.155844  0.103896  0.000000
# 68    0.000000  0.222222  0.111111
# 69    0.136364  0.090909  0.011364
# 70    0.020408  0.071429  0.051020
# 71    0.103448  0.000000  0.000000
#
# [72 rows x 113 columns]

# %%
mumbai_grouped.shape
# Out:
# (72, 113)

# %% [markdown]
# Let see the top 5 amenities for each neighbourhood

# %%
num_top_venues = 5

for hood in mumbai_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = mumbai_grouped[mumbai_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----1, Narayan Nagar, Mumbra, Thane, Maharashtra 400612, India----
#                    venue  freq
# 0         All Restaurant  0.50
# 1                 Snacks  0.25
# 2          Train Station  0.25
# 3                    ATM  0.00
# 4  Outdoors & Recreation  0.00
#
#
# ----1, Pokharan Rd Number 1, Shastri Nagar, Vartak Nagar, Thane West, Thane, Maharashtra 400606, India----
#             venue  freq
# 0  All Restaurant  0.40
# 1          Snacks  0.24
# 2        Shopping  0.13
# 3      Night life  0.13
# 4       Multiplex  0.03
#
#
# ----10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregaon, Maharashtra 400065, India----
#                  venue  freq
# 0       All Restaurant  0.34
# 1               Snacks  0.28
# 2        Design Studio  0.03
# 3  Indie Movie Theater  0.03
# 4           Smoke Shop  0.03
#
#
# ----12, Sakharam Lanjekar Road, Parmanand Wadi, Parel, Maharashtra 400012, India----
#             venue  freq
# 0          Snacks  0.41
# 1  All Restaurant  0.31
# 2      Night life  0.08
# 3        Shopping  0.06
# 4           Plaza  0.04
#
#
# ----184/B, Sant Rohidas Marg, Dharavi koliwada, Dharavi Village, Dharavi, Maharashtra 400017, India----
#             venue  freq
# 0  All Restaurant  0.48
# 1          Snacks  0.22
# 2      Night life  0.07
# 3        Shopping  0.04
# 4   Train Station  0.03
#
#
# ----1st Floor, St. Lawrence High School 90 Feet Road, Opposite Kanakia Sanskruti Thakur Complex, Asha Nagar, Kandivali East, Maharashtra 400101, India----
#             venue  freq
# 0          Snacks  0.30
# 1  All Restaurant  0.27
# 2        Shopping  0.16
# 3      Night life  0.06
# 4         All_Gym  0.03
#
#
# ----2, HMA Faqir St, The Mahim Makarand CHS, Mahim West, Mahim, Maharashtra 400016, India----
#             venue  freq
# 0          Snacks  0.36
# 1  All Restaurant  0.33
# 2      Night life  0.11
# 3  Scenic Lookout  0.02
# 4        Shopping  0.02
#
#
# ----209, Dinshaw Vacha Rd, Churchgate, Maharashtra 400020, India----
#             venue  freq
# 0  All Restaurant  0.33
# 1          Snacks  0.26
# 2      Night life  0.11
# 3        Shopping  0.05
# 4  Cricket Ground  0.03
#
#
# ----25, Prakash Thorat Marg, Gaikwad nagar, Budha Nagar, Chedda Nagar, Maharashtra 400071, India----
#             venue  freq
# 0  All Restaurant  0.41
# 1          Snacks  0.27
# 2        Shopping  0.07
# 3      Night life  0.07
# 4         All_Gym  0.05
#
#
# ----329, Subhash Nagar, Mohili, Asalpha, Maharashtra 400084, India----
#             venue  freq
# 0  All Restaurant  0.39
# 1          Snacks  0.20
# 2      Night life  0.15
# 3        Shopping  0.11
# 4         Brewery  0.02
#
#
# ----400060, Sarvodaya Nagar, MHADA Colony, Indira Nagar, Jogeshwari East, Maharashtra 400093, India----
#                 venue  freq
# 0      All Restaurant  0.46
# 1              Snacks  0.22
# 2          Night life  0.15
# 3             All_Gym  0.04
# 4  Athletics & Sports  0.02
#
#
# ----400065, Workers Colony, Aarey Colony, Goregaon, Maharashtra 400065, India----
#             venue  freq
# 0  All Restaurant  0.29
# 1          Snacks  0.14
# 2         All_Gym  0.07
# 3    Dance Studio  0.07
# 4            Lake  0.07
#
#
# ----428, KN Gaikwad Marg, Ganesh Nagar, Postal Colony, Chembur, Maharashtra 400071, India----
#             venue  freq
# 0  All Restaurant  0.40
# 1          Snacks  0.22
# 2        Shopping  0.09
# 3      Night life  0.07
# 4         All_Gym  0.03
#
#
# ----446, Govind Patil Rd, Patil Pada, Danda Village, Khar Danda, Maharashtra 400052, India----
#             venue  freq
# 0          Snacks  0.34
# 1  All Restaurant  0.33
# 2      Night life  0.15
# 3        Shopping  0.07
# 4         All_Gym  0.02
#
#
# ----515/A, Shankar Ghanekar Rd, Three View Co-Operative Housing Society, Opposite Bengal Chemicals, Dadar (w), Prabhadevi, Maharashtra 400025, India----
#             venue  freq
# 0          Snacks  0.39
# 1  All Restaurant  0.34
# 2      Night life  0.10
# 3        Shopping  0.07
# 4  Scenic Lookout  0.02
#
#
# ----703, Bhardawadi Rd, ICICI Colony, Amboli, Andheri West, Maharashtra 400058, India----
#             venue  freq
# 0  All Restaurant  0.38
# 1          Snacks  0.24
# 2      Night life  0.15
# 3        Shopping  0.07
# 4         All_Gym  0.04
#
#
# ----802, B3, MM Valley, Nr TMC Stadium, Jilani Park Rd, Kausa, Mumbra, Thane, Maharashtra 400612, India----
#                            venue  freq
# 0                 All Restaurant  0.50
# 1                            ATM  0.25
# 2                         Snacks  0.25
# 3  Paper / Office Supplies Store  0.00
# 4              Recreation Center  0.00
#
#
# ----A Hill Crest, Holy cross Road I.C.Colony, near MM hospital, Borivali West, Maharashtra 400103, India----
#             venue  freq
# 0          Snacks  0.39
# 1  All Restaurant  0.25
# 2      Night life  0.09
# 3         All_Gym  0.08
# 4        Shopping  0.05
#
#
# ----A-402, Krishna Vatika Marg, Snehadham, Azad Nagar, Gokuldham Colony, Goregaon, Maharashtra 400063, India----
#             venue  freq
# 0          Snacks  0.33
# 1  All Restaurant  0.29
# 2      Night life  0.09
# 3         All_Gym  0.07
# 4        Shopping  0.07
#
#
# ----Anant Niwas Rana Nagar No. 1, Reti Bunder Road, Rana Nagar, Retibunder, Mumbra, Thane, Maharashtra 400612, India----
#             venue  freq
# 0          Snacks  0.43
# 1       Bookstore  0.14
# 2   Big Box Store  0.14
# 3  All Restaurant  0.14
# 4       Multiplex  0.14
#
#
# ----Andheri - Kurla Rd, Jarimari, Saki Naka, Maharashtra 400072, India----
#              venue  freq
# 0   All Restaurant  0.37
# 1       Night life  0.24
# 2           Snacks  0.19
# 3         Shopping  0.05
# 4  Airport Service  0.03
#
#
# ----B-21, Bhatwadi, Barve Nagar, Ghatkopar West, Maharashtra 400084, India----
#             venue  freq
# 0  All Restaurant  0.37
# 1          Snacks  0.23
# 2      Night life  0.16
# 3        Shopping  0.12
# 4         All_Gym  0.02
#
#
# ----B/23, Highway Apartment., 2nd floor., Eastern Express Highway, Sion (E, Maharashtra 400022, India----
#             venue  freq
# 0  All Restaurant  0.38
# 1          Snacks  0.21
# 2      Night life  0.12
# 3         All_Gym  0.04
# 4   Train Station  0.04
#
#
# ----B5-WING, Kharegaon, Kalwa, Thane, Maharashtra 400605, India----
#            venue  freq
# 0         Snacks  0.27
# 1       Shopping  0.18
# 2   Tennis Court  0.09
# 3  Moving Target  0.09
# 4  Train Station  0.09
#
#
# ----Bandra - Worli Sea Link, Mount Mary, Bandra West, Maharashtra 400050, India----
#             venue  freq
# 0          Snacks  0.31
# 1  All Restaurant  0.28
# 2      Night life  0.15
# 3  Scenic Lookout  0.05
# 4        Shopping  0.05
#
#
# ----Bdb Gate 1, G Block BKC, Bandra Kurla Complex, Bandra East, Maharashtra 400051, India----
#             venue  freq
# 0  All Restaurant  0.35
# 1          Snacks  0.31
# 2      Night life  0.14
# 3        Shopping  0.04
# 4         All_Gym  0.02
#
#
# ----Bunglow no. 786, Aqsa Masjid Rd, Behind Medow Park, Gautam Nagar, Jogeshwari, Maharashtra 400102, India----
#             venue  freq
# 0  All Restaurant  0.34
# 1          Snacks  0.28
# 2      Night life  0.15
# 3         All_Gym  0.09
# 4        Shopping  0.06
#
#
# ----C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, Vile Parle East, Maharashtra 400057, India----
#                venue  freq
# 0             Snacks  0.42
# 1     All Restaurant  0.32
# 2         Night life  0.16
# 3           Shopping  0.06
# 4  Martial Arts Dojo  0.01
#
#
# ----C-46, LBS Rd, Godrej & Boyce Industry Estate, Vikhroli West, Maharashtra 400079, India----
#             venue  freq
# 0  All Restaurant  0.32
# 1          Snacks  0.28
# 2      Night life  0.16
# 3        Shopping  0.09
# 4         All_Gym  0.01
#
#
# ----Casa Bella Magnifica Bus Stop, Casa Bella Main Rd, Casa Bella, PHI, Casa Bella, Usarghar, Maharashtra 421204, India----
#                            venue  freq
# 0                        All_Gym  0.25
# 1                       Shopping  0.25
# 2                 All Restaurant  0.25
# 3                      Multiplex  0.25
# 4  Paper / Office Supplies Store  0.00
#
#
# ----Centre Cable of Bandra Worli Sea Link, Bandra - Worli Sea Link, 400050, India----
#             venue  freq
# 0          Snacks  0.42
# 1      Night life  0.18
# 2  All Restaurant  0.18
# 3  Scenic Lookout  0.06
# 4         All_Gym  0.03
#
#
# ----Cuffe Parade, Cuffe Parade, Maharashtra 400005, India----
#             venue  freq
# 0  All Restaurant  0.35
# 1          Snacks  0.26
# 2      Night life  0.20
# 3        Shopping  0.06
# 4             Spa  0.02
#
#
# ----D-83, Muranjan Wadi, Marol, Andheri East, Maharashtra 400072, India----
#             venue  freq
# 0  All Restaurant  0.43
# 1      Night life  0.24
# 2          Snacks  0.19
# 3        Shopping  0.06
# 4       Multiplex  0.01
#
#
# ----Dadlani Park, Raheja Complex, Majiwada, Thane, Maharashtra 400608, India----
#             venue  freq
# 0        Shopping  0.25
# 1          Snacks  0.25
# 2       Multiplex  0.25
# 3         All_Gym  0.12
# 4  All Restaurant  0.12
#
#
# ----Eskay Rd, Eksar Village, Eksar, Borivali West, Maharashtra 400103, India----
#             venue  freq
# 0  All Restaurant  0.38
# 1          Snacks  0.26
# 2         All_Gym  0.06
# 3      Night life  0.06
# 4      Playground  0.03
#
#
# ----Gavdevi Road, Betwade Gaon, Thane, Maharashtra 400612, India----
#                         venue  freq
# 0                    Shopping  0.50
# 1              All Restaurant  0.25
# 2  Tourist Information Center  0.25
# 3                         ATM  0.00
# 4       Outdoors & Recreation  0.00
#
#
# ----Ghartan Pada / Chinchani Number 1, Diamond Industrial Estate, Dahisar East, Maharashtra 400068, India----
#                           venue  freq
# 0                All Restaurant  0.30
# 1                        Snacks  0.23
# 2                    Night life  0.17
# 3                      Shopping  0.13
# 4  General College & University  0.03
#
#
# ----Government Colony Building No 3, JL Shirshekar Marg, Government Colony, Bandra East, Maharashtra 400051, India----
#             venue  freq
# 0  All Restaurant  0.36
# 1          Snacks  0.29
# 2      Night life  0.22
# 3         All_Gym  0.04
# 4        Shopping  0.02
#
#
# ----Hashimpremji, Shop No-2, Navpada, Vile Parle East, Vile Parle, Maharashtra 400099, India----
#              venue  freq
# 0   All Restaurant  0.38
# 1       Night life  0.24
# 2           Snacks  0.19
# 3         Shopping  0.06
# 4  Airport Service  0.02
#
#
# ----JAMAATE GHURABA ALHEHADEES MADARSA MUHAMMADIA WA MASJID 1/22, LAXMI NAGAR, LINK ROAD, BESIDE GARDEN ESTATES APARTMENT NEAR, BEDROCK TYRE CO, Colony No 2, Laxmi Nagar, Goregaon West, Maharashtra 400104, India----
#             venue  freq
# 0          Snacks  0.32
# 1  All Restaurant  0.31
# 2         All_Gym  0.08
# 3        Shopping  0.08
# 4      Night life  0.08
#
#
# ----Kachra Depot Rd, Govandi Slums, Nirankar Nagar, Shivaji Nagar, Maharashtra 400043, India----
#                            venue  freq
# 0                         Snacks  0.67
# 1                 All Restaurant  0.33
# 2                            ATM  0.00
# 3  Paper / Office Supplies Store  0.00
# 4              Recreation Center  0.00
#
#
# ----LE ROUGE TRENDZ PVT.LTD.Ground Floor,Rounak Business Centre,Opp.Cine, Wonder,Nex, Thane, Maharashtra 400607, India----
#             venue  freq
# 0          Snacks  0.54
# 1      Night life  0.15
# 2         All_Gym  0.08
# 3        Shopping  0.08
# 4  All Restaurant  0.08
#
#
# ----Lower Parel, Lower Parel Bridge, Lower Parel, Maharashtra 400013, India----
#             venue  freq
# 0  All Restaurant  0.31
# 1          Snacks  0.28
# 2      Night life  0.16
# 3        Shopping  0.07
# 4       Multiplex  0.02
#
#
# ----Lucky Towers, MG Cross Rd Number 4, Amrut Nagar, Patel Nagar, Kandivali, Maharashtra 400067, India----
#             venue  freq
# 0  All Restaurant  0.41
# 1          Snacks  0.31
# 2        Shopping  0.10
# 3      Night life  0.05
# 4       Multiplex  0.02
#
#
# ----Mangal Prabha, Prabhat Colony Rd, Sen Nagar, Santacruz East, Maharashtra 400055, India----
#             venue  freq
# 0          Snacks  0.33
# 1      Night life  0.24
# 2  All Restaurant  0.24
# 3        Shopping  0.10
# 4         All_Gym  0.04
#
#
# ----Maroshi Naka, Unit 25, Aarey Colony, Goregaon, Maharashtra 400065, India----
#             venue  freq
# 0  All Restaurant  0.45
# 1          Snacks  0.20
# 2      Night life  0.18
# 3         All_Gym  0.08
# 4     Golf Course  0.02
#
#
# ----National Park - BMC Colony Rd, Maharashtra 400101, India----
#             venue  freq
# 0          Snacks  0.29
# 1  All Restaurant  0.19
# 2        Shopping  0.14
# 3      Night life  0.12
# 4         All_Gym  0.05
#
#
# ----Navpada, Chhatrapati Shivaji International Airport Area, Vile Parle, Maharashtra 400099, India----
#             venue  freq
# 0  All Restaurant  0.38
# 1      Night life  0.26
# 2          Snacks  0.17
# 3        Shopping  0.05
# 4         Airport  0.02
#
#
# ----New Dock Rd, Victoria Docks Port Trust, Mazgaon, Maharashtra 400009, India----
#              venue  freq
# 0   All Restaurant  0.36
# 1  Harbor / Marina  0.21
# 2         Shopping  0.14
# 3       Night life  0.14
# 4           Snacks  0.07
#
#
# ----P and T Colony Rd, P and T Colony, Chhatrapati Shivaji International Airport Area, Santacruz East, Maharashtra 400029, India----
#             venue  freq
# 0          Snacks  0.32
# 1  All Restaurant  0.30
# 2      Night life  0.20
# 3         Airport  0.04
# 4         All_Gym  0.02
#
#
# ----PL Lokhande Marg, ACC Nagar, Chedda Nagar, Maharashtra 400043, India----
#             venue  freq
# 0  All Restaurant  0.40
# 1          Snacks  0.28
# 2      Night life  0.08
# 3        Shopping  0.07
# 4         All_Gym  0.06
#
#
# ----Premier Colony, Kurla West, Maharashtra 400070, India----
#             venue  freq
# 0  All Restaurant  0.43
# 1          Snacks  0.23
# 2        Shopping  0.12
# 3      Night life  0.12
# 4         All_Gym  0.03
#
#
# ----Rolex Apartment, Underai Rd, Malad, Navy Colony, Mamledarwadi, Malad West, Maharashtra 400064, India----
#             venue  freq
# 0          Snacks  0.30
# 1  All Restaurant  0.28
# 2        Shopping  0.15
# 3      Night life  0.12
# 4       Multiplex  0.06
#
#
# ----Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Chand Hotel, Near Mahim Dargah, LJ Cross Rd, Mahim, Maharashtra 400016, India----
#             venue  freq
# 0  All Restaurant  0.39
# 1          Snacks  0.34
# 2      Night life  0.07
# 3        Shopping  0.06
# 4         All_Gym  0.03
#
#
# ----Room no 645 rajive gandhi nagar Near New Transist Camp Antop hill Wadala, East, Maharashtra 400037, India----
#             venue  freq
# 0  All Restaurant  0.39
# 1          Snacks  0.31
# 2        Shopping  0.11
# 3         All_Gym  0.03
# 4      Night life  0.03
#
#
# ----Rushi Van Borivali, Rushi Van, Next to Kajupada, Borivali East, Maharashtra 400066, India----
#             venue  freq
# 0          Snacks  0.21
# 1      Night life  0.14
# 2  All Restaurant  0.14
# 3      Lighthouse  0.07
# 4   Historic Site  0.07
#
#
# ----Saket - Kalwa Rd, Rabodi, Thane West, Thane, Maharashtra 400601, India----
#             venue  freq
# 0          Snacks  0.32
# 1  All Restaurant  0.32
# 2      Night life  0.10
# 3        Shopping  0.09
# 4       Multiplex  0.05
#
#
# ----Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar, Bhuleshwar, Maharashtra 400003, India----
#                  venue  freq
# 0       All Restaurant  0.37
# 1               Snacks  0.32
# 2             Shopping  0.08
# 3           Night life  0.08
# 4  Indie Movie Theater  0.02
#
#
# ----Shiv Shakti Shopping Complex, Deepak Kumar Marg, Swastik Park, Chembur, Maharashtra 400071, India----
#             venue  freq
# 0  All Restaurant  0.37
# 1          Snacks  0.23
# 2        Shopping  0.09
# 3      Night life  0.07
# 4         All_Gym  0.03
#
#
# ----Shop No. 1, Ground Floor, Vallabh Vihar, Opp. Kotak Mahindra Bank, MG Road, Rajawadi Colony, Ghatkopar East, Maharashtra 400077, India----
#             venue  freq
# 0  All Restaurant  0.44
# 1          Snacks  0.29
# 2        Shopping  0.10
# 3      Night life  0.10
# 4         All_Gym  0.02
#
#
# ----Shop Number.21 A Wing Kamaraj CHS Near JPR Radios, 90 Feet Road, Dharavi, Maharashtra 400017, India----
#             venue  freq
# 0  All Restaurant  0.47
# 1          Snacks  0.27
# 2        Shopping  0.08
# 3      Night life  0.04
# 4   Train Station  0.04
#
#
# ----Shri Ganesh Rahivasi Seva Sangh, Khale Compound, Next Nakshatra Residency, Near Talwalkars Gym, Panch Pakhdi, Thane West, Maharashtra 400602, India----
#             venue  freq
# 0  All Restaurant  0.42
# 1          Snacks  0.28
# 2      Night life  0.11
# 3        Shopping  0.09
# 4       Multiplex  0.03
#
#
# ----Tikuji Ni Wadi Rd, Manpada, Thane West, Thane, Maharashtra 400607, India----
#             venue  freq
# 0          Snacks  0.36
# 1  All Restaurant  0.33
# 2        Shopping  0.09
# 3      Night life  0.09
# 4         All_Gym  0.02
#
#
# ----Unnamed Road, Anjur, Maharashtra 421302, India----
#                         venue  freq
# 0               Train Station  0.29
# 1  Tourist Information Center  0.14
# 2                    Shopping  0.14
# 3                  Smoke Shop  0.14
# 4              All Restaurant  0.14
#
#
# ----Unnamed Road, Domkhar Gaon, Thane, Maharashtra 421204, India----
#                                       venue  freq
# 0                            All Restaurant   0.6
# 1                                   All_Gym   0.2
# 2                               Bus Station   0.2
# 3                                      Park   0.0
# 4  Residential Building (Apartment / Condo)   0.0
#
#
# ----Unnamed Road, Fort, Maharashtra 400001, India----
#                  venue  freq
# 0       All Restaurant  0.34
# 1               Snacks  0.29
# 2           Night life  0.16
# 3             Shopping  0.06
# 4  Monument / Landmark  0.02
#
#
# ----Unnamed Road, Malad, Shivaji Nagar, Kurar Village, Malad East, Maharashtra 400097, India----
#             venue  freq
# 0          Snacks  0.39
# 1  All Restaurant  0.25
# 2        Shopping  0.16
# 3         All_Gym  0.04
# 4       Multiplex  0.04
#
#
# ----Unnamed Road, Pereira Wadi, Asalpha, Maharashtra 400072, India----
#             venue  freq
# 0  All Restaurant  0.36
# 1          Snacks  0.22
# 2      Night life  0.16
# 3        Shopping  0.10
# 4            Bank  0.01
#
#
# ----Unnamed Road, Pratiksha Nagar, BPCL Terminal, Wadala, Maharashtra 400015, India----
#            venue  freq
# 0         Snacks  0.33
# 1       Shopping  0.22
# 2        All_Gym  0.11
# 3     Smoke Shop  0.11
# 4  Train Station  0.11
#
#
# ----Vile Parle East, Vile Parle, Maharashtra, India----
#             venue  freq
# 0  All Restaurant  0.32
# 1          Snacks  0.31
# 2      Night life  0.14
# 3        Shopping  0.09
# 4         Airport  0.02
#
#
# ----garden grove, b-1, flat no. 1301, b-wing, chikuwadi, borivali west, Maharashtra 400092, India----
#             venue  freq
# 0  All Restaurant  0.37
# 1          Snacks  0.32
# 2        Shopping  0.07
# 3         All_Gym  0.05
# 4      Night life  0.02
#
#
# ----pollution response team Near mazagon Dock, Maharashtra, India----
#               venue  freq
# 0            Snacks  0.41
# 1    All Restaurant  0.34
# 2        Night life  0.10
# 3  Community Center  0.03
# 4       Music Venue  0.03

# %% [markdown]
# Now we will find most common venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 15

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = mumbai_grouped['Neighborhood']

for ind in np.arange(mumbai_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(mumbai_grouped.iloc[ind, :], num_top_venues)

print(len(neighborhoods_venues_sorted))
neighborhoods_venues_sorted.head(10)
# Out:
# 72
#                                         Neighborhood 1st Most Common Venue  \
# 0  1, Narayan Nagar, Mumbra, Thane, Maharashtra 4...        All Restaurant
# 1  1, Pokharan Rd Number 1, Shastri Nagar, Vartak...        All Restaurant
# 2  10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregao...        All Restaurant
# 3  12, Sakharam Lanjekar Road, Parmanand Wadi, Pa...                Snacks
# 4  184/B, Sant Rohidas Marg, Dharavi koliwada, Dh...        All Restaurant
# 5  1st Floor, St. Lawrence High School 90 Feet Ro...                Snacks
# 6  2, HMA Faqir St, The Mahim Makarand CHS, Mahim...                Snacks
# 7  209, Dinshaw Vacha Rd, Churchgate, Maharashtra...        All Restaurant
# 8  25, Prakash Thorat Marg, Gaikwad nagar, Budha ...        All Restaurant
# 9  329, Subhash Nagar, Mohili, Asalpha, Maharasht...        All Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 0                Snacks         Train Station                All_Gym
# 1                Snacks            Night life               Shopping
# 2                Snacks            Smoke Shop                  Plaza
# 3        All Restaurant            Night life               Shopping
# 4                Snacks            Night life               Shopping
# 5        All Restaurant              Shopping             Night life
# 6        All Restaurant            Night life  Performing Arts Venue
# 7                Snacks            Night life               Shopping
# 8                Snacks            Night life               Shopping
# 9                Snacks            Night life               Shopping
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                  Farm      Community Center     Convention Center
# 1            Sports Bar             Multiplex               Brewery
# 2            Night life   Indie Movie Theater                  Farm
# 3         Train Station                 Plaza               All_Gym
# 4         Train Station               All_Gym                Garden
# 5               All_Gym                  Park               Stadium
# 6          Gourmet Shop              Shopping        Scenic Lookout
# 7        Cricket Ground             Bookstore               Theater
# 8               All_Gym                  Park                Garden
# 9             Multiplex               Brewery         Bowling Alley
#
#   8th Most Common Venue 9th Most Common Venue     10th Most Common Venue  \
# 0        Cosmetics Shop       Coworking Space                   Creperie
# 1        Scenic Lookout        Soccer Stadium                    Factory
# 2              Shopping              Boutique                Bus Station
# 3             Roof Deck     Recreation Center            Airport Service
# 4                Arcade               Brewery                  Multiplex
# 5             Multiplex            Smoke Shop                   Pharmacy
# 6                 Beach                   Spa                 Playground
# 7        Scenic Lookout              Boutique  College Academic Building
# 8                   Spa            Playground      Performing Arts Venue
# 9               All_Gym           Bus Station                 Shoe Store
#
#                      11th Most Common Venue 12th Most Common Venue  \
# 0                            Cricket Ground           Dance Studio
# 1                            Cricket Ground        Coworking Space
# 2                              Dance Studio          Design Studio
# 3                                      Farm      Convention Center
# 4                               Bus Station     Miscellaneous Shop
# 5  Residential Building (Apartment / Condo)             Sports Bar
# 6                        College Auditorium                   Park
# 7                     Performing Arts Venue                   Park
# 8                          Sculpture Garden                  Plaza
# 9                                Sports Bar                   Bank
#
#   13th Most Common Venue 14th Most Common Venue 15th Most Common Venue
# 0          Design Studio         Duty-free Shop            Event Space
# 1           Dance Studio         Cosmetics Shop      Convention Center
# 2     Athletics & Sports              Multiplex            Event Space
# 3         Cosmetics Shop        Coworking Space               Creperie
# 4            Sports Club                   Park    Indie Movie Theater
# 5          Train Station              Bookstore  General Entertainment
# 6               Boutique                All_Gym                  Track
# 7                All_Gym            Music Store                  Beach
# 8            Golf Course  General Entertainment            Fish Market
# 9               Platform             Theme Park          Design Studio

# %% [markdown]
# ## Methodology <a name="methodology"></a>
# We will use K-clustering approach to resolve our problem. We will cluster our neighbourhood in 20 clusters and then analyse which cluster is best fit to our requirements

# %% [markdown]
# Now, cluster the neighbourhood using K-cluster approach

# %%
# set number of clusters
kclusters = 20

mumbai_grouped_clustering = mumbai_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(mumbai_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# array([16, 12,  1,  1, 12], dtype=int32)

# %% [markdown]
# Add this cluster numbers to our dataset

# %%
# add clustering labels

neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

mumbai_merged = df_locations
mumbai_merged

mumbai_merged = mumbai_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Address')

mumbai_merged.head() # check the last columns!
# Out:
#                                              Address   Latitude  Longitude  \
# 0    Vile Parle East, Vile Parle, Maharashtra, India  19.089736  72.856490
# 1  C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, ...  19.107987  72.850532
# 2  Navpada, Chhatrapati Shivaji International Air...  19.095397  72.875682
# 3  703, Bhardawadi Rd, ICICI Colony, Amboli, Andh...  19.126246  72.844576
# 4  Unnamed Road, Pereira Wadi, Asalpha, Maharasht...  19.101049  72.894872
#
#               X             Y  Distance from center  Cluster Labels  \
# 0  7.515072e+06  3.673569e+06           5000.000000               9
# 1  7.512572e+06  3.676069e+06           3535.533906               1
# 2  7.517572e+06  3.676069e+06           3535.533906              15
# 3  7.510072e+06  3.678569e+06           5000.000000               9
# 4  7.520072e+06  3.678569e+06           5000.000000               9
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  ...  \
# 0        All Restaurant                Snacks            Night life  ...
# 1                Snacks        All Restaurant            Night life  ...
# 2        All Restaurant            Night life                Snacks  ...
# 3        All Restaurant                Snacks            Night life  ...
# 4        All Restaurant                Snacks            Night life  ...
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0         Train Station               Airport               All_Gym
# 1        Duty-free Shop     Martial Arts Dojo             Multiplex
# 2        Duty-free Shop       Airport Service    Light Rail Station
# 3             Multiplex              Pharmacy               Brewery
# 4                  Bank                  Pool                Resort
#
#   9th Most Common Venue                    10th Most Common Venue  \
# 0        Airport Lounge                            Duty-free Shop
# 1               All_Gym                             Design Studio
# 2                Resort                                   Brewery
# 3           Sports Club  Residential Building (Apartment / Condo)
# 4               Brewery                             Bowling Alley
#
#   11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 0                Theater  Outdoors & Recreation      Martial Arts Dojo
# 1                Factory            Event Space               Creperie
# 2                    Spa             Theme Park                   Pool
# 3      Accessories Store               Boutique            Event Space
# 4                 Office             Shoe Store           Soccer Field
#
#   14th Most Common Venue 15th Most Common Venue
# 0    Arts & Crafts Store           Dance Studio
# 1           Dance Studio         Cricket Ground
# 2         Airport Lounge          Bowling Alley
# 3               Creperie         Cricket Ground
# 4              Multiplex      Accessories Store
#
# [5 rows x 22 columns]

# %% [markdown]
# Visualise the clusters

# %%
map_clusters = folium.Map(location=mumbai_coordinate, zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
print(rainbow)
markers_colors = []
for lat, lon, poi, cluster in zip(mumbai_merged['Latitude'], mumbai_merged['Longitude'], mumbai_merged['Address'], mumbai_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# ['#8000ff', '#6629fe', '#4c50fc', '#3079f7', '#169bf2', '#07bbea', '#20d5e1', '#3dead5', '#56f7ca', '#72febb', '#8cfead', '#a8f79c', '#c2ea8c', '#ded579', '#f9bb66', '#ff9b52', '#ff793e', '#ff5029', '#ff2914', '#ff0000']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analysis <a name="analysis"></a>
# Now we will evalue each cluster and see what fit best to our requirement

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 0, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 18  1st Floor, St. Lawrence High School 90 Feet Ro...           3535.533906
# 20  National Park - BMC Colony Rd, Maharashtra 400...           5000.000000
# 61  Rolex Apartment, Underai Rd, Malad, Navy Colon...           3535.533906
# 63  Unnamed Road, Malad, Shivaji Nagar, Kurar Vill...           5000.000000
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18               0                Snacks        All Restaurant
# 20               0                Snacks        All Restaurant
# 61               0                Snacks        All Restaurant
# 63               0                Snacks        All Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18              Shopping            Night life               All_Gym
# 20              Shopping            Night life               All_Gym
# 61              Shopping            Night life             Multiplex
# 63              Shopping               All_Gym             Multiplex
#
#    6th Most Common Venue 7th Most Common Venue  8th Most Common Venue  \
# 18                  Park               Stadium              Multiplex
# 20               Stadium   Indie Movie Theater  General Entertainment
# 61               All_Gym             Bookstore         Cosmetics Shop
# 63            Night life           Bus Station                Brewery
#
#    9th Most Common Venue 10th Most Common Venue  \
# 18            Smoke Shop               Pharmacy
# 20            Lighthouse                   Park
# 61               Brewery             Smoke Shop
# 63             Bookstore                  Train
#
#                       11th Most Common Venue 12th Most Common Venue  \
# 18  Residential Building (Apartment / Condo)             Sports Bar
# 20  Residential Building (Apartment / Condo)             Sports Bar
# 61                                Sports Bar            Gaming Cafe
# 63                                Playground            Event Space
#
#     13th Most Common Venue 14th Most Common Venue 15th Most Common Venue
# 18           Train Station              Bookstore  General Entertainment
# 20           Historic Site    Arts & Crafts Store            Art Gallery
# 61  Furniture / Home Store      Convention Center           Gourmet Shop
# 63                Creperie         Cosmetics Shop         Cricket Ground

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 1, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 1   C 107,Neeta co. Op. SoC. Tajpalschemerd. No5, ...           3535.533906
# 10  2, HMA Faqir St, The Mahim Makarand CHS, Mahim...           3535.533906
# 13  446, Govind Patil Rd, Patil Pada, Danda Villag...           3535.533906
# 17  garden grove, b-1, flat no. 1301, b-wing, chik...           3535.533906
# 21  A Hill Crest, Holy cross Road I.C.Colony, near...           3535.533906
# 29  Sardar Vallabhbhai Patel Rd, Ajmer, Null Bazar...           3535.533906
# 31  pollution response team Near mazagon Dock, Mah...           5000.000000
# 33  515/A, Shankar Ghanekar Rd, Three View Co-Oper...           3535.533906
# 34  12, Sakharam Lanjekar Road, Parmanand Wadi, Pa...           3535.533906
# 37  Room No. 11, 4, B.M.C Bldg., 2nd Floor Opp. Ch...           3535.533906
# 57  JAMAATE GHURABA ALHEHADEES MADARSA MUHAMMADIA ...           3535.533906
# 58  10, Bimbisar Nagar Rd, Bimbisar Nagar, Goregao...           3535.533906
# 62  A-402, Krishna Vatika Marg, Snehadham, Azad Na...           3535.533906
# 74  Saket - Kalwa Rd, Rabodi, Thane West, Thane, M...           3535.533906
# 77  Tikuji Ni Wadi Rd, Manpada, Thane West, Thane,...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1                1                Snacks        All Restaurant
# 10               1                Snacks        All Restaurant
# 13               1                Snacks        All Restaurant
# 17               1        All Restaurant                Snacks
# 21               1                Snacks        All Restaurant
# 29               1        All Restaurant                Snacks
# 31               1                Snacks        All Restaurant
# 33               1                Snacks        All Restaurant
# 34               1                Snacks        All Restaurant
# 37               1        All Restaurant                Snacks
# 57               1                Snacks        All Restaurant
# 58               1        All Restaurant                Snacks
# 62               1                Snacks        All Restaurant
# 74               1                Snacks        All Restaurant
# 77               1                Snacks        All Restaurant
#
#    3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 1             Night life               Shopping               Airport
# 10            Night life  Performing Arts Venue          Gourmet Shop
# 13            Night life               Shopping               All_Gym
# 17              Shopping                All_Gym            Night life
# 21            Night life                All_Gym              Shopping
# 29            Night life               Shopping   Indie Movie Theater
# 31            Night life            Fish Market                Garden
# 33            Night life               Shopping        Scenic Lookout
# 34            Night life               Shopping         Train Station
# 37            Night life               Shopping               All_Gym
# 57               All_Gym             Night life              Shopping
# 58            Smoke Shop                  Plaza            Night life
# 62            Night life                All_Gym              Shopping
# 74            Night life               Shopping             Multiplex
# 77            Night life               Shopping               All_Gym
#
#    6th Most Common Venue                     7th Most Common Venue  \
# 1         Duty-free Shop                         Martial Arts Dojo
# 10              Shopping                            Scenic Lookout
# 13                Arcade                            Scenic Lookout
# 17                  Park                                Sports Bar
# 21         Train Station                                    Arcade
# 29       Harbor / Marina                                    Garden
# 31           Music Venue                          Community Center
# 33               All_Gym                                   Theater
# 34                 Plaza                                   All_Gym
# 37                 Beach                                   Theater
# 57             Multiplex                                 Bookstore
# 58   Indie Movie Theater                                      Farm
# 62             Multiplex                                   Brewery
# 74            Sports Bar                                   Theater
# 77            Theme Park  Residential Building (Apartment / Condo)
#
#      8th Most Common Venue  9th Most Common Venue  \
# 1                Multiplex                All_Gym
# 10                   Beach                    Spa
# 13  Furniture / Home Store         Farmers Market
# 17           Historic Site     Miscellaneous Shop
# 21            Optical Shop  Outdoors & Recreation
# 29             Bridal Shop            Music Venue
# 31            Gourmet Shop                Factory
# 33             Music Venue                 Office
# 34               Roof Deck      Recreation Center
# 37   Performing Arts Venue          Boat or Ferry
# 57                  Garden          Design Studio
# 58                Shopping               Boutique
# 62             Event Space              Bookstore
# 74            Optical Shop                Brewery
# 77                 Theater            Bus Station
#
#            10th Most Common Venue 11th Most Common Venue  \
# 1                   Design Studio                Factory
# 10                     Playground     College Auditorium
# 13          General Entertainment            Event Space
# 17                      Multiplex               Pharmacy
# 21  Paper / Office Supplies Store           Soccer Field
# 29                    Music Store              Multiplex
# 31              Convention Center         Cosmetics Shop
# 33                        Brewery     Athletics & Sports
# 34                Airport Service                   Farm
# 37                         Arcade             Playground
# 57                     Smoke Shop         Cosmetics Shop
# 58                    Bus Station           Dance Studio
# 62                           Farm                 Office
# 74                            Spa            Art Gallery
# 77                     Water Park        Airport Service
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 1             Event Space               Creperie           Dance Studio
# 10                   Park               Boutique                All_Gym
# 13     Salon / Barbershop          Design Studio           Dance Studio
# 17             Playground                 Bridge               Boutique
# 21             Sports Bar            Bus Station                Theater
# 29                  Beach                 Arcade            Opera House
# 31        Coworking Space               Creperie         Cricket Ground
# 33                Stadium      Recreation Center            Art Gallery
# 34      Convention Center         Cosmetics Shop        Coworking Space
# 37                  Track                 Garden            Event Space
# 57         Cricket Ground                Factory           Dance Studio
# 58          Design Studio     Athletics & Sports              Multiplex
# 62                 Garden           Gourmet Shop         Cosmetics Shop
# 74           Tennis Court         Soccer Stadium                   Lake
# 77                   Farm      Convention Center         Cosmetics Shop
#
#    15th Most Common Venue
# 1          Cricket Ground
# 10                  Track
# 13               Creperie
# 17         Shop & Service
# 21            Art Gallery
# 29           Antique Shop
# 31           Dance Studio
# 33                 Arcade
# 34               Creperie
# 37      Convention Center
# 57        Coworking Space
# 58            Event Space
# 62        Coworking Space
# 74               Pharmacy
# 77        Coworking Space

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 2, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 5   400060, Sarvodaya Nagar, MHADA Colony, Indira ...           3535.533906
# 7   Maroshi Naka, Unit 25, Aarey Colony, Goregaon,...           5000.000000
# 19  Eskay Rd, Eksar Village, Eksar, Borivali West,...           5000.000000
# 64  B/23, Highway Apartment., 2nd floor., Eastern ...           5000.000000
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 5                2        All Restaurant                Snacks
# 7                2        All Restaurant                Snacks
# 19               2        All Restaurant                Snacks
# 64               2        All Restaurant                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5             Night life               All_Gym                Garden
# 7             Night life               All_Gym                Resort
# 19               All_Gym            Night life            Theme Park
# 64            Night life               All_Gym         Train Station
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5           Dance Studio              Boutique           Music Venue
# 7            Golf Course          Dance Studio                Garden
# 19             Multiplex            Playground            Sports Bar
# 64                Garden                  Park            Smoke Shop
#
#    9th Most Common Venue 10th Most Common Venue        11th Most Common Venue  \
# 5     Athletics & Sports             Public Art  General College & University
# 7               Creperie         Duty-free Shop                 Design Studio
# 19                Arcade                 Bridge                     Pool Hall
# 64          Soccer Field              Bookstore                       Brewery
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 5             Gaming Cafe       Community Center      Convention Center
# 7          Cricket Ground         Cosmetics Shop        Coworking Space
# 19             Water Park         Duty-free Shop         Cosmetics Shop
# 64  Performing Arts Venue               Shopping                  Train
#
#    15th Most Common Venue
# 5          Cosmetics Shop
# 7                 Factory
# 19        Coworking Space
# 64                   Pool

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 3, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 46  Gavdevi Road, Betwade Gaon, Thane, Maharashtra...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 46               3              Shopping        All Restaurant
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 46  Tourist Information Center        Farmers Market     Convention Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 46        Cosmetics Shop       Coworking Space              Creperie
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 46        Cricket Ground           Dance Studio          Design Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 46         Duty-free Shop            Event Space                Factory
#
#    15th Most Common Venue
# 46                   Farm

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 4, 
        mumbai_merged.columns[[1] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#      Latitude  Distance from center  Cluster Labels 1st Most Common Venue  \
# 45  19.205171           3535.533906               4         Train Station
# 47  19.210720           5000.000000               4         Train Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 45              Shopping       Harbor / Marina        All Restaurant
# 47              Shopping       Harbor / Marina        All Restaurant
#
#    5th Most Common Venue       6th Most Common Venue 7th Most Common Venue  \
# 45            Smoke Shop  Tourist Information Center               All_Gym
# 47            Smoke Shop  Tourist Information Center               All_Gym
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 45        Cricket Ground        Duty-free Shop          Design Studio
# 47        Cricket Ground        Duty-free Shop          Design Studio
#
#    11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 45           Dance Studio        Coworking Space               Creperie
# 47           Dance Studio        Coworking Space               Creperie
#
#    14th Most Common Venue 15th Most Common Venue
# 45                Factory         Cosmetics Shop
# 47                Factory         Cosmetics Shop

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 5, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 36  Unnamed Road, Pratiksha Nagar, BPCL Terminal, ...                5000.0
# 76  B5-WING, Kharegaon, Kalwa, Thane, Maharashtra ...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 36               5                Snacks              Shopping
# 76               5                Snacks              Shopping
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 36               All_Gym         Train Station            Smoke Shop
# 76         Big Box Store         Moving Target         Train Station
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 36                 Trail     Convention Center        Cosmetics Shop
# 76          Tennis Court             Multiplex                  Farm
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 36               Factory        Coworking Space               Creperie
# 76               Factory            Event Space         Duty-free Shop
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 36         Cricket Ground           Dance Studio          Design Studio
# 76                All_Gym          Design Studio         Farmers Market
#
#    15th Most Common Venue
# 36         Duty-free Shop
# 76         Cricket Ground

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 6, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 8   Centre Cable of Bandra Worli Sea Link, Bandra ...                5000.0
# 79  LE ROUGE TRENDZ PVT.LTD.Ground Floor,Rounak Bu...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8                6                Snacks            Night life
# 79               6                Snacks            Night life
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8         All Restaurant        Scenic Lookout               All_Gym
# 79               All_Gym        All Restaurant              Shopping
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8               Boutique               Stadium                 Beach
# 79           Bus Station        Cricket Ground           Event Space
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 8               Shopping        Coworking Space                Factory
# 79        Duty-free Shop          Design Studio           Dance Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 8          Cricket Ground           Dance Studio          Design Studio
# 79        Coworking Space               Creperie                   Farm
#
#    15th Most Common Venue
# 8          Cosmetics Shop
# 79         Cosmetics Shop

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 7, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 44  Casa Bella Magnifica Bus Stop, Casa Bella Main...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 44               7               All_Gym        All Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 44             Multiplex              Shopping               Airport
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 44     Convention Center       Coworking Space              Creperie
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 44        Cricket Ground           Dance Studio          Design Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 44         Duty-free Shop            Event Space                Factory
#
#    15th Most Common Venue
# 44                   Farm

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 8, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 42  Unnamed Road, Domkhar Gaon, Thane, Maharashtra...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 42               8        All Restaurant               All_Gym
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 42           Bus Station        Farmers Market     Convention Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 42        Cosmetics Shop       Coworking Space              Creperie
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 42        Cricket Ground           Dance Studio          Design Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 42         Duty-free Shop            Event Space                Factory
#
#    15th Most Common Venue
# 42                   Farm

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 9, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 0     Vile Parle East, Vile Parle, Maharashtra, India           5000.000000
# 3   703, Bhardawadi Rd, ICICI Colony, Amboli, Andh...           5000.000000
# 4   Unnamed Road, Pereira Wadi, Asalpha, Maharasht...           5000.000000
# 14  Government Colony Building No 3, JL Shirshekar...           3535.533906
# 15  Mangal Prabha, Prabhat Colony Rd, Sen Nagar, S...           5000.000000
# 23  Ghartan Pada / Chinchani Number 1, Diamond Ind...           5000.000000
# 24  Cuffe Parade, Cuffe Parade, Maharashtra 400005...           5000.000000
# 25  209, Dinshaw Vacha Rd, Churchgate, Maharashtra...           3535.533906
# 26      Unnamed Road, Fort, Maharashtra 400001, India           3535.533906
# 32  Lower Parel, Lower Parel Bridge, Lower Parel, ...           5000.000000
# 35  Bandra - Worli Sea Link, Mount Mary, Bandra We...           5000.000000
# 53  B-21, Bhatwadi, Barve Nagar, Ghatkopar West, M...           3535.533906
# 55  C-46, LBS Rd, Godrej & Boyce Industry Estate, ...           5000.000000
# 56  Bunglow no. 786, Aqsa Masjid Rd, Behind Medow ...           5000.000000
# 65  Bdb Gate 1, G Block BKC, Bandra Kurla Complex,...           3535.533906
# 67  P and T Colony Rd, P and T Colony, Chhatrapati...           5000.000000
# 71  329, Subhash Nagar, Mohili, Asalpha, Maharasht...           5000.000000
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0                9        All Restaurant                Snacks
# 3                9        All Restaurant                Snacks
# 4                9        All Restaurant                Snacks
# 14               9        All Restaurant                Snacks
# 15               9                Snacks            Night life
# 23               9        All Restaurant                Snacks
# 24               9        All Restaurant                Snacks
# 25               9        All Restaurant                Snacks
# 26               9        All Restaurant                Snacks
# 32               9        All Restaurant                Snacks
# 35               9                Snacks        All Restaurant
# 53               9        All Restaurant                Snacks
# 55               9        All Restaurant                Snacks
# 56               9        All Restaurant                Snacks
# 65               9        All Restaurant                Snacks
# 67               9                Snacks        All Restaurant
# 71               9        All Restaurant                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0             Night life              Shopping            Smoke Shop
# 3             Night life              Shopping               All_Gym
# 4             Night life              Shopping    Light Rail Station
# 14            Night life               All_Gym              Shopping
# 15        All Restaurant              Shopping               All_Gym
# 23            Night life              Shopping           Bus Station
# 24            Night life              Shopping                   Spa
# 25            Night life              Shopping        Cricket Ground
# 26            Night life              Shopping             Bookstore
# 32            Night life              Shopping             Multiplex
# 35            Night life              Shopping        Scenic Lookout
# 53            Night life              Shopping               All_Gym
# 55            Night life              Shopping               All_Gym
# 56            Night life               All_Gym              Shopping
# 65            Night life              Shopping               All_Gym
# 67            Night life               Airport               All_Gym
# 71            Night life              Shopping             Multiplex
#
#     6th Most Common Venue 7th Most Common Venue         8th Most Common Venue  \
# 0           Train Station               Airport                       All_Gym
# 3               Multiplex              Pharmacy                       Brewery
# 4                    Bank                  Pool                        Resort
# 14                   Park                Arcade                       Brewery
# 15    Arts & Crafts Store        Duty-free Shop         Outdoors & Recreation
# 23  Outdoors & Recreation         Train Station  General College & University
# 24                Theater           Art Gallery         Performing Arts Venue
# 25              Bookstore               Theater                Scenic Lookout
# 26    Monument / Landmark               All_Gym                  Tennis Court
# 32                    Spa               All_Gym                   Comedy Club
# 35                All_Gym         Boat or Ferry                      Boutique
# 53          Bowling Alley            Theme Park                     Multiplex
# 55             Sports Bar             Multiplex                      Creperie
# 56              Multiplex               Brewery                         Track
# 65                    Spa   Indie Movie Theater                        Garden
# 67               Shopping        Duty-free Shop         Outdoors & Recreation
# 71                Brewery         Bowling Alley                       All_Gym
#
#    9th Most Common Venue                    10th Most Common Venue  \
# 0         Airport Lounge                            Duty-free Shop
# 3            Sports Club  Residential Building (Apartment / Condo)
# 4                Brewery                             Bowling Alley
# 14             Bookstore                               Sports Club
# 15            Sports Bar                                   Airport
# 23                  Road                                  Creperie
# 24        Cricket Ground                                  Boutique
# 25              Boutique                 College Academic Building
# 26                  Park                      Other Great Outdoors
# 32             Roof Deck                         Recreation Center
# 35               Stadium                     Performing Arts Venue
# 53          Soccer Field                                Sports Bar
# 55       Coworking Space                                     Plaza
# 56                   Spa                                  Pharmacy
# 65             Multiplex                                      Park
# 67      Airport Terminal                            Airport Lounge
# 71           Bus Station                                Shoe Store
#
#    11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 0                 Theater  Outdoors & Recreation      Martial Arts Dojo
# 3       Accessories Store               Boutique            Event Space
# 4                  Office             Shoe Store           Soccer Field
# 14    Indie Movie Theater           Antique Shop            Art Gallery
# 15            Golf Course                Factory         Cosmetics Shop
# 23          Design Studio           Dance Studio         Cricket Ground
# 24         Scenic Lookout    Monument / Landmark                Stadium
# 25  Performing Arts Venue                   Park                All_Gym
# 26               Boutique                  Field                Stadium
# 32                  Plaza            Music Venue            Planetarium
# 35                  Beach         Cricket Ground           Dance Studio
# 53                Factory                Brewery         Duty-free Shop
# 55                Brewery          Bowling Alley           Soccer Field
# 56         Cosmetics Shop                Factory               Creperie
# 65  Performing Arts Venue            Bus Station              Roof Deck
# 67          Train Station             Smoke Shop                   Farm
# 71             Sports Bar                   Bank               Platform
#
#    14th Most Common Venue 15th Most Common Venue
# 0     Arts & Crafts Store           Dance Studio
# 3                Creperie         Cricket Ground
# 4               Multiplex      Accessories Store
# 14               Creperie         Cricket Ground
# 15        Coworking Space               Creperie
# 23                All_Gym        Coworking Space
# 24                All_Gym         History Museum
# 25            Music Store                  Beach
# 26                    Spa            Art Gallery
# 32         Cosmetics Shop                 Office
# 35          Design Studio               Creperie
# 53          Design Studio         Cricket Ground
# 55                   Bank                    Spa
# 56         Cricket Ground        Coworking Space
# 65                Brewery        Business Center
# 67        Coworking Space               Creperie
# 71             Theme Park          Design Studio

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 10, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 43  Anant Niwas Rana Nagar No. 1, Reti Bunder Road...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 43              10                Snacks         Big Box Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 43        All Restaurant             Multiplex             Bookstore
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 43               All_Gym        Cosmetics Shop       Coworking Space
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 43              Creperie         Cricket Ground           Dance Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 43          Design Studio         Duty-free Shop            Event Space
#
#    15th Most Common Venue
# 43                Factory

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 11, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 52  Kachra Depot Rd, Govandi Slums, Nirankar Nagar...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 52              11                Snacks        All Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 52               All_Gym        Farmers Market     Convention Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 52        Cosmetics Shop       Coworking Space              Creperie
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 52        Cricket Ground           Dance Studio          Design Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 52         Duty-free Shop            Event Space                Factory
#
#    15th Most Common Venue
# 52                   Farm

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 12, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 12  184/B, Sant Rohidas Marg, Dharavi koliwada, Dh...           5000.000000
# 16  Lucky Towers, MG Cross Rd Number 4, Amrut Naga...           5000.000000
# 38  Room no 645 rajive gandhi nagar Near New Trans...           3535.533906
# 39  Shop Number.21 A Wing Kamaraj CHS Near JPR Rad...           5000.000000
# 48  428, KN Gaikwad Marg, Ganesh Nagar, Postal Col...           5000.000000
# 49  Premier Colony, Kurla West, Maharashtra 400070...           3535.533906
# 50  PL Lokhande Marg, ACC Nagar, Chedda Nagar, Mah...           3535.533906
# 66  Shiv Shakti Shopping Complex, Deepak Kumar Mar...           3535.533906
# 68  25, Prakash Thorat Marg, Gaikwad nagar, Budha ...           5000.000000
# 70  Shop No. 1, Ground Floor, Vallabh Vihar, Opp. ...           3535.533906
# 72  Shri Ganesh Rahivasi Seva Sangh, Khale Compoun...           5000.000000
# 73  1, Pokharan Rd Number 1, Shastri Nagar, Vartak...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 12              12        All Restaurant                Snacks
# 16              12        All Restaurant                Snacks
# 38              12        All Restaurant                Snacks
# 39              12        All Restaurant                Snacks
# 48              12        All Restaurant                Snacks
# 49              12        All Restaurant                Snacks
# 50              12        All Restaurant                Snacks
# 66              12        All Restaurant                Snacks
# 68              12        All Restaurant                Snacks
# 70              12        All Restaurant                Snacks
# 72              12        All Restaurant                Snacks
# 73              12        All Restaurant                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12            Night life              Shopping         Train Station
# 16              Shopping            Night life             Multiplex
# 38              Shopping               All_Gym            Night life
# 39              Shopping         Train Station            Night life
# 48              Shopping            Night life               All_Gym
# 49            Night life              Shopping               All_Gym
# 50            Night life              Shopping               All_Gym
# 66              Shopping            Night life               All_Gym
# 68            Night life              Shopping               All_Gym
# 70            Night life              Shopping               All_Gym
# 72            Night life              Shopping             Multiplex
# 73            Night life              Shopping            Sports Bar
#
#    6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 12               All_Gym                 Garden                 Arcade
# 16         Train Station     Miscellaneous Shop         Cosmetics Shop
# 38         Train Station     Miscellaneous Shop         Baseball Field
# 39               All_Gym    Indie Movie Theater                  Train
# 48                Garden  Performing Arts Venue     Light Rail Station
# 49            Theme Park  Performing Arts Venue          Bowling Alley
# 50                  Park                 Garden                    Spa
# 66          Soccer Field                 Garden  Performing Arts Venue
# 68                  Park                 Garden                    Spa
# 70            Playground       Sculpture Garden              Multiplex
# 72            Sports Bar                All_Gym                Theater
# 73             Multiplex                Brewery         Scenic Lookout
#
#     9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 12                Brewery              Multiplex            Bus Station
# 16            Bus Station                   Park            Gaming Cafe
# 38      Convention Center         Farmers Market            Gaming Cafe
# 39              Bookstore                 Garden                 Arcade
# 48             Playground                    Spa            Golf Course
# 49       Sculpture Garden             Shoe Store             Playground
# 50  Performing Arts Venue       Sculpture Garden                  Plaza
# 66     Light Rail Station  General Entertainment                   Pool
# 68             Playground  Performing Arts Venue       Sculpture Garden
# 70          Bowling Alley             Theme Park           Dance Studio
# 72                Brewery         Soccer Stadium                    Spa
# 73         Soccer Stadium                Factory         Cricket Ground
#
#     12th Most Common Venue  13th Most Common Venue 14th Most Common Venue  \
# 12      Miscellaneous Shop             Sports Club                   Park
# 16             Art Gallery                 All_Gym           Liquor Store
# 38                  Garden     Indie Movie Theater     Light Rail Station
# 39      Miscellaneous Shop             Sports Club            Gaming Cafe
# 48                   Plaza                    Pool    Arts & Crafts Store
# 49                  Garden  Furniture / Home Store       Community Center
# 50  Furniture / Home Store          Cricket Ground       Community Center
# 66              Shoe Store     Arts & Crafts Store             Smoke Shop
# 68                   Plaza             Golf Course  General Entertainment
# 70           Design Studio         Coworking Space         Cricket Ground
# 72  Furniture / Home Store          Duty-free Shop       Community Center
# 73         Coworking Space            Dance Studio         Cosmetics Shop
#
#    15th Most Common Venue
# 12    Indie Movie Theater
# 16                 Garden
# 38                Stadium
# 39         Duty-free Shop
# 48             Smoke Shop
# 49      Convention Center
# 50      Convention Center
# 66                    Spa
# 68            Fish Market
# 70               Creperie
# 72      Convention Center
# 73      Convention Center

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 13, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 30  New Dock Rd, Victoria Docks Port Trust, Mazgao...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 30              13        All Restaurant       Harbor / Marina
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 30            Night life              Shopping                 Plaza
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 30                Snacks              Creperie        Duty-free Shop
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 30         Design Studio           Dance Studio         Cricket Ground
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 30                All_Gym        Coworking Space         Cosmetics Shop
#
#    15th Most Common Venue
# 30                Factory

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 14, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 60  400065, Workers Colony, Aarey Colony, Goregaon...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 60              14        All Restaurant                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 60               All_Gym                Resort           Golf Course
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 60   Monument / Landmark                  Farm           Event Space
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 60          Dance Studio                   Lake                 Arcade
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 60            Art Gallery               Creperie         Cricket Ground
#
#    15th Most Common Venue
# 60       Airport Terminal

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 15, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 2   Navpada, Chhatrapati Shivaji International Air...           3535.533906
# 6   D-83, Muranjan Wadi, Marol, Andheri East, Maha...           3535.533906
# 51  Andheri - Kurla Rd, Jarimari, Saki Naka, Mahar...           5000.000000
# 69  Hashimpremji, Shop No-2, Navpada, Vile Parle E...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2               15        All Restaurant            Night life
# 6               15        All Restaurant            Night life
# 51              15        All Restaurant            Night life
# 69              15        All Restaurant            Night life
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2                 Snacks              Shopping               Airport
# 6                 Snacks              Shopping    Light Rail Station
# 51                Snacks              Shopping       Airport Service
# 69                Snacks              Shopping       Airport Service
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2         Duty-free Shop       Airport Service    Light Rail Station
# 6                 Resort                Office        Scenic Lookout
# 51    Light Rail Station           Music Store             Multiplex
# 69    Light Rail Station                Resort        Duty-free Shop
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 2                 Resort                Brewery                    Spa
# 6              Multiplex                Brewery                 Garden
# 51        Duty-free Shop                    Spa                 Resort
# 69         Bowling Alley                Brewery                    Spa
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 2              Theme Park                   Pool         Airport Lounge
# 6           Train Station         Duty-free Shop               Creperie
# 51             Theme Park          Bowling Alley                   Pool
# 69             Theme Park                   Pool         Airport Lounge
#
#    15th Most Common Venue
# 2           Bowling Alley
# 6          Cricket Ground
# 51         Airport Lounge
# 69                Airport

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 16, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 41  1, Narayan Nagar, Mumbra, Thane, Maharashtra 4...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 41              16        All Restaurant                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 41         Train Station               All_Gym                  Farm
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 41      Community Center     Convention Center        Cosmetics Shop
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 41       Coworking Space               Creperie         Cricket Ground
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 41           Dance Studio          Design Studio         Duty-free Shop
#
#    15th Most Common Venue
# 41            Event Space

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 17, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 78  Dadlani Park, Raheja Complex, Majiwada, Thane,...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 78              17              Shopping                Snacks
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 78             Multiplex               All_Gym        All Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 78          Dance Studio               Factory           Event Space
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 78        Duty-free Shop          Design Studio               Creperie
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 78         Cricket Ground         Farmers Market        Coworking Space
#
#    15th Most Common Venue
# 78         Cosmetics Shop

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 18, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 40  802, B3, MM Valley, Nr TMC Stadium, Jilani Par...                5000.0
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 40              18        All Restaurant                   ATM
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 40                Snacks        Farmers Market     Convention Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 40        Cosmetics Shop       Coworking Space              Creperie
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 40        Cricket Ground           Dance Studio          Design Studio
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 40         Duty-free Shop            Event Space                Factory
#
#    15th Most Common Venue
# 40                   Farm

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'] == 19, 
        mumbai_merged.columns[[0] + list(range(5, mumbai_merged.shape[1]))]]
# Out:
#                                               Address  Distance from center  \
# 22  Rushi Van Borivali, Rushi Van, Next to Kajupad...           3535.533906
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 22              19                Snacks            Night life
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 22        All Restaurant               All_Gym              Shopping
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 22        Scenic Lookout            Lighthouse         Historic Site
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 22         Train Station    Indie Movie Theater      Convention Center
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 22                Factory         Cosmetics Shop        Coworking Space
#
#    15th Most Common Venue
# 22               Creperie

# %% [markdown]
# Considering discussion with stakeholders, Basic needs are food shopping and Gym, Neighbourhood of cluster 0, 12 and 19 is considered as best neighbourhood.

# %%
mumbai_merged.loc[mumbai_merged['Cluster Labels'].isin([0, 12, 19]), 
        mumbai_merged.columns[[0]]]['Address']
# Out:
# 12    184/B, Sant Rohidas Marg, Dharavi koliwada, Dh...
# 16    Lucky Towers, MG Cross Rd Number 4, Amrut Naga...
# 18    1st Floor, St. Lawrence High School 90 Feet Ro...
# 20    National Park - BMC Colony Rd, Maharashtra 400...
# 22    Rushi Van Borivali, Rushi Van, Next to Kajupad...
# 38    Room no 645 rajive gandhi nagar Near New Trans...
# 39    Shop Number.21 A Wing Kamaraj CHS Near JPR Rad...
# 48    428, KN Gaikwad Marg, Ganesh Nagar, Postal Col...
# 49    Premier Colony, Kurla West, Maharashtra 400070...
# 50    PL Lokhande Marg, ACC Nagar, Chedda Nagar, Mah...
# 61    Rolex Apartment, Underai Rd, Malad, Navy Colon...
# 63    Unnamed Road, Malad, Shivaji Nagar, Kurar Vill...
# 66    Shiv Shakti Shopping Complex, Deepak Kumar Mar...
# 68    25, Prakash Thorat Marg, Gaikwad nagar, Budha ...
# 70    Shop No. 1, Ground Floor, Vallabh Vihar, Opp. ...
# 72    Shri Ganesh Rahivasi Seva Sangh, Khale Compoun...
# 73    1, Pokharan Rd Number 1, Shastri Nagar, Vartak...
# Name: Address, dtype: object

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Our analysis shows some good option which are good places to live in. These are some places which has good access of trains also find all the venues of entertainments near there place. For this we have found all trains stations in mumbai specially which are connented to 2 major train lines in mumbai. Then we have found 5 km areas cenreting the station which will have great access to that train station.
# Foursquare is used to find amenities of all those neighbourhood. Result is then clustered into 20 clusters and found best areas which has all amenities as discussed by stakeholder. Result location are best candidate area for live in in mumbai

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to find best neighbourhood in Mumbai. Major creteria is have less travelling time, considering heave traffic in Mumbai. Less travelling time include travel time to local station and travel time to gym, restaturants, shopping etc. So train places near traing station are considered as best candidate. It is further narrow down using foursquare data for amenities near the candidate neighbourhood.
#
# Final decision will be made by stakeholders based on specific requirement of neighbourhood and locations in every recommended zone, taking into consideration additional factors like price, area, office location, levels of noise, social and economic dynamics of every neighborhood etc.
